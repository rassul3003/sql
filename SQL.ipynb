# %%
import seaborn as sns
sns.set()

# %%
from static_grader import grader

# %% [markdown]
# # SQL Miniproject

# %% [markdown]
# ## Introduction

# %% [markdown]
# The city of New York does restaurant inspections and assigns a grade. Inspections data for various years are available on s3 as an SQLite database, which you can import in the next few cells. These were extracted from a set of CSV files and an XLS file, as described in the <b>How we loaded the data</b> section
#
# The raw data can be found [here](https://s3.amazonaws.com/dataincubator-course/coursedata/nyc_inspection_data.zip) and can be useful to look at. The file `RI_Webextract_BigApps_Latest.xls` contains a description of each of the data files and what the columns mean.

# %%
#This will load the pre-existing tables
# %load_ext sql
# %sql postgresql://docker:docker@nycinspection.tditrain.com:5433/NYCinspection

# %% [markdown]
# To see what tables are in the database:

# %%
# %%sql
#
# SELECT table_name FROM information_schema.tables
# WHERE table_schema = 'public';
# Out:
#  * postgresql://docker:***@nycinspection.tditrain.com:5433/NYCinspection
# 4 rows affected.
# [('webextract',), ('violations',), ('cuisine',), ('boroughs',)]

# %% [markdown]
# And to look at the format of an individual table (note that you may need to change types to get the answers in the right form):

# %%
# %%sql
#
# SELECT column_name, data_type FROM information_schema.columns
# WHERE table_name = 'webextract'
# ORDER BY ordinal_position;
# Out:
#  * postgresql://docker:***@nycinspection.tditrain.com:5433/NYCinspection
# 15 rows affected.
# [('camis', 'integer'),
#  ('dba', 'text'),
#  ('boro', 'integer'),
#  ('building', 'text'),
#  ('street', 'text'),
#  ('zipcode', 'text'),
#  ('phone', 'text'),
#  ('cuisinecode', 'integer'),
#  ('inspdate', 'timestamp without time zone'),
#  ('action', 'text'),
#  ('violcode', 'text'),
#  ('score', 'integer'),
#  ('currentgrade', 'text'),
#  ('gradedate', 'timestamp without time zone'),
#  ('recorddate', 'timestamp without time zone')]

# %% [markdown]
# ### Submission format
#
# For all questions other than the first, the grader is expecting a table of results.  This can be in the form of a Python list of lists or a DataFrame.  The output format of the SQL magic (that is, cells that start with `%%sql`) is also accepted by the grader.
#
# Recall that in IPython notebooks, the output of the previously-run cell is stored in the variable `_`.  We can capture the output of the previous query, for example by running:

# %%
result = _

# %% [markdown]
# This object can be indexed or iterated, and thus your answer can be built.

# %%
result[0][0]
# Out:
# 'camis'

# %% [markdown]
# If your query produces output of the right shape, you can submit this full result direct to the grader without any intermediate steps.
#
# **Note:** All questions have a placeholder solution provided to demonstrate the correct shape for your answer.  Be sure to submit the answer you've computed, not the placeholder!
#
# **Warning:** If any returned query has thousands of rows, you run the risk of your browser locking up. To prevent your browser from locking up, use `LIMIT` to control the number of records that are returned and displayed.

# %% [markdown]
# ### Aside: How we loaded the data

# %% [markdown]
# As you may notice, the original data come in CSV files.  There are a number of ways to load CSV files into a SQL database; we'll demonstrate a few here.  For concreteness, let's suppose we have a CSV file `sample.csv` with the following contents:
# ```
# Name,Age
# Alice,3
# Bob,10
# ```
#
# SQLite has a convenient [`.import` function](https://sqlite.org/cli.html#csv_import) which can create tables from `.csv` files.
#
# ```bash
# sqlite> .import sample.csv sample
# sqlite> SELECT * FROM sample;
# ```
#
# In PostgreSQL, you need to create a table and then [copy](https://www.postgresql.org/docs/current/app-psql.html#APP-PSQL-META-COMMANDS-COPY) the data into it.
# ```
# postgres=> CREATE TABLE sample (name TEXT, age INT);
# postgres=> \copy sample FROM 'sample.csv' WITH CSV HEADER;
# ```
#
# Alternatively, you can also read CSV files using pandas and convert that into SQL via some [SQL magic](https://github.com/catherinedevlin/ipython-sql#pandas).
#
# ```python
# import pandas as pd
#
# %load_ext sql
# %sql sqlite:///sample.db
#
# sample = pd.read_csv('sample.csv')
#
# %sql DROP TABLE IF EXISTS sample;
# %sql --persist sample
# %sql SELECT * FROM sample;
# ```
#
# Note that many CSV files contain badly formatted text.  Unfortunately, this is all too common.  The [`iconv`](https://linux.die.net/man/1/iconv) utility can convert files between different text encodings, and tools like [`awk`](https://linux.die.net/man/1/awk) and [`sed`](https://linux.die.net/man/1/sed) are useful for text transformation operations.

# %% [markdown]
# ## Question 1: Null entries

# %% [markdown]
# Return the number of inspections (`CAMIS`, `INSPDATE` pairs) that do not have a score - i.e. where none of the rows with those (`CAMIS`, `INSPDATE`) values has a score. Remove the corresponding rows from the data set for the rest of the questions in the assignment.
#
# > **Note:**  This database is _read-only_, so you cannot modify the database to "remove" the rows.  You should instead make a temporary table (or temporary view) that does this "removal" process and use that temporary table for the remainder of the questions.
#
# As an example, we might see this in our data:
#
# ```sql
# SELECT CAMIS, INSPDATE, SCORE
# FROM webextract
# ORDER BY CAMIS, INSPDATE
# LIMIT 10;
# ```
#
# | `CAMIS` | `INSPDATE` | `SCORE` |
# | --- | --- | --- |
# | 30075445 | 2011-03-10 00:00:00 | 14.0 |
# | 30075445 | 2011-03-10 00:00:00 | 14.0 |
# | 30075445 | 2011-03-10 00:00:00 | 14.0 |
# | 30075445 | 2011-03-10 00:00:00 | None |
# | 30075445 | 2011-04-27 00:00:00 | None |
# | 30075445 | 2011-11-12 00:00:00 | None |
# | 30075445 | 2011-11-12 00:00:00 | None |
# | 30075445 | 2011-11-23 00:00:00 | 9.0 |
# | 30075445 | 2011-11-23 00:00:00 | 9.0 |
# | 30075445 | 2011-11-23 00:00:00 | 9.0 |
#
# We want to filter only those dates for a given `CAMIS` where _every_ score is NULL (or `None` in the Python output).  In this case, we would remove 2011-04-27 and 2011-11-12, but keep 2011-03-10 (and 2011-11-23, of course).  Our post-filtering table would be:
#
# | `CAMIS` | `INSPDATE` | `SCORE` |
# | --- | --- | --- |
# | 30075445 | 2011-03-10 00:00:00 | 14.0 |
# | 30075445 | 2011-03-10 00:00:00 | 14.0 |
# | 30075445 | 2011-03-10 00:00:00 | 14.0 |
# | 30075445 | 2011-03-10 00:00:00 | None |
# | 30075445 | 2011-11-23 00:00:00 | 9.0 |
# | 30075445 | 2011-11-23 00:00:00 | 9.0 |
# | 30075445 | 2011-11-23 00:00:00 | 9.0 |
#
# **Question:** How else might we have handled this?

# %%
# %%sql
#
# select count(*)
# from webextract;
# Out:
#  * postgresql://docker:***@nycinspection.tditrain.com:5433/NYCinspection
# 1 rows affected.
# [(531935,)]

# %%
# %%sql
#
# select count(*)
# from webextract
# where score IS NOT NULL;
# Out:
#  * postgresql://docker:***@nycinspection.tditrain.com:5433/NYCinspection
# 1 rows affected.
# [(498411,)]

# %%
# %%sql
#
# -- 1st way
# -- creating a 'nulls' table by removing the rows where all combinations of camis and inspdate do not have a score
# -- join webextract with itself
#
# DROP TABLE IF EXISTS nulls;
# CREATE TEMPORARY TABLE nulls AS
#
# SELECT DISTINCT w1.camis, w1.inspdate, w1.score
# FROM webextract w1
# LEFT JOIN webextract w2 ON w1.camis = w2.camis
#                        AND w1.inspdate = w2.inspdate
#                        AND w2.score IS NOT NULL
# WHERE w2.camis IS NULL;
# Out:
#  * postgresql://docker:***@nycinspection.tditrain.com:5433/NYCinspection
# Done.
# 8255 rows affected.
# []

# %%
# %%sql
#
# -- 2nd way
# -- creating a 'nulls' table by removing the rows where all combinations of camis and inspdate do not have a score
#
# DROP TABLE IF EXISTS nulls;
# CREATE TEMPORARY TABLE nulls AS
#
# SELECT DISTINCT camis, inspdate, score
# FROM webextract
# WHERE (camis, inspdate) NOT IN (
#     SELECT DISTINCT camis, inspdate
#     FROM webextract
#     WHERE score IS NOT NULL
# );
# Out:
#  * postgresql://docker:***@nycinspection.tditrain.com:5433/NYCinspection
# Done.
# 8255 rows affected.
# []

# %%
# %%sql
#
# -- counting the number of rows in 'temp_table' table
#
# select count(*) from nulls;
# Out:
#  * postgresql://docker:***@nycinspection.tditrain.com:5433/NYCinspection
# 1 rows affected.
# [(8255,)]

# %%
# store the result of the query as a python variable

result = _

# %%
# get the number stored in this table

null_entries = result[0][0]

# %%
#null_entries = 

grader.score('sql__null_entries', null_entries)
# Out:
# ==================
# Your score: 1.0000
# ==================

# %% [markdown]
# ## Question 2: Score by ZIP code

# %% [markdown]
# Return a list of tuples of the form:
#
#     (ZIP code, mean score, number of restaurants)
#
# for each of the 87 ZIP codes in the city with over 100 restaurants (we'll call these "valid ZIP codes"). Use the score from the latest inspection date for each restaurant. Sort the list in ascending order by mean score.
#
# **Note:** There is an interesting discussion here about what the mean score *means* in this data set. Think about what we're actually calculating - does it represent what we're trying to understand about these ZIP codes?
#
# What if we use the average of a restaurant's inspections instead of the latest?
#
# **Checkpoints:**
# - Total unique restaurants: 24,361
# - Total restaurants in valid ZIP codes: 19,172

# %%
# %%sql
#
# -- creating a table named no_nulls where the (camis, inspdate) has a score or webextract table minus temp_table
#
# DROP TABLE IF EXISTS filtered;
#
# CREATE TEMPORARY TABLE filtered AS
#
# SELECT *
# FROM webextract
# WHERE (camis, inspdate, score) NOT IN (
#     SELECT camis, inspdate, score
#     FROM nulls
# );
# Out:
#  * postgresql://docker:***@nycinspection.tditrain.com:5433/NYCinspection
# Done.
# 522812 rows affected.
# []

# %%
# %%sql
#
# -- output top 10 rows of a 'no_nulls' table to glimpse the data
#
# select * from filtered
# limit 10;
# Out:
#  * postgresql://docker:***@nycinspection.tditrain.com:5433/NYCinspection
# 10 rows affected.
# [(41613314, 'AMSTERDAM GOURMET', 1, '401403    ', 'AMSTERDAM AVENUE                                                                                    ', '10024', '2123621525', 75, datetime.datetime(2011, 12, 7, 0, 0), 'F', '04L', 25, 'B', datetime.datetime(2011, 12, 7, 0, 0), datetime.datetime(2014, 9, 4, 6, 1, 28, 403000)),
#  (41594064, 'KULU DESSERTS', 3, '806       ', '62 STREET                                                                                           ', '11220', '7186802818', 43, datetime.datetime(2012, 6, 14, 0, 0), 'D', '10F', 12, 'A', datetime.datetime(2012, 6, 14, 0, 0), datetime.datetime(2014, 9, 4, 6, 1, 28, 403000)),
#  (41594110, "CASALE'S BAKERY & SPECIALTY FOODS", 5, '96', 'PAGE AVENUE', '10309', '7183563700', 8, datetime.datetime(2012, 1, 26, 0, 0), 'D', '10D', 9, 'A', datetime.datetime(2012, 1, 26, 0, 0), datetime.datetime(2014, 9, 4, 6, 1, 28, 403000)),
#  (41594110, "CASALE'S BAKERY & SPECIALTY FOODS", 5, '96', 'PAGE AVENUE', '10309', '7183563700', 8, datetime.datetime(2013, 3, 13, 0, 0), 'D', '06E', 5, 'A', datetime.datetime(2013, 3, 13, 0, 0), datetime.datetime(2014, 9, 4, 6, 1, 28, 403000)),
#  (41594415, 'FOUR & TWENTY BLACKBIRDS', 3, '439', '3 AVENUE', '11215', '7184992917', 8, datetime.datetime(2011, 10, 13, 0, 0), 'D', '10F', 12, 'A', datetime.datetime(2011, 10, 13, 0, 0), datetime.datetime(2014, 9, 4, 6, 1, 28, 403000)),
#  (41594415, 'FOUR & TWENTY BLACKBIRDS', 3, '439', '3 AVENUE', '11215', '7184992917', 8, datetime.datetime(2013, 4, 25, 0, 0), 'D', '10F', 9, 'A', datetime.datetime(2013, 4, 25, 0, 0), datetime.datetime(2014, 9, 4, 6, 1, 28, 403000)),
#  (41594416, 'NACIONES UNIDAS', 4, '112-07    ', 'JAMAICA AVENUE                                    ', '11418', '7184415160', 55, datetime.datetime(2011, 8, 18, 0, 0), 'E', '10B', 30, None, None, datetime.datetime(2014, 9, 4, 6, 1, 28, 403000)),
#  (41594416, 'NACIONES UNIDAS', 4, '112-07    ', 'JAMAICA AVENUE                                    ', '11418', '7184415160', 55, datetime.datetime(2011, 8, 25, 0, 0), 'D', '10F', 4, None, None, datetime.datetime(2014, 9, 4, 6, 1, 28, 403000)),
#  (41594416, 'NACIONES UNIDAS', 4, '112-07    ', 'JAMAICA AVENUE                                    ', '11418', '7184415160', 55, datetime.datetime(2013, 10, 17, 0, 0), 'D', '15L', None, None, None, datetime.datetime(2014, 9, 4, 6, 1, 28, 403000)),
#  (41594416, 'NACIONES UNIDAS', 4, '112-07    ', 'JAMAICA AVENUE                                    ', '11418', '7184415160', 55, datetime.datetime(2013, 10, 17, 0, 0), 'P', '06C', 20, None, None, datetime.datetime(2014, 9, 4, 6, 1, 28, 403000))]

# %%
# %%sql
#
# -- checking the total number of unique restaurants in the no_nulls table - 24361
#
# select count(distinct camis) from filtered limit 10;
# Out:
#  * postgresql://docker:***@nycinspection.tditrain.com:5433/NYCinspection
# 1 rows affected.
# [(24361,)]

# %%
# %%sql
#
# -- checking the total number of unique restaurants in every zipcode with more than 100 restaurants - 87
# -- at the same time creating a temp table to count unique restaurants in every zip code ('valid zip codes')
#
# DROP TABLE IF EXISTS number_of_camis;
# Create temporary table number_of_camis as
#
# select zipcode, count(distinct camis) as camis_per_zip
# from filtered
# group by zipcode
# having count(distinct camis) > 100
# Out:
#  * postgresql://docker:***@nycinspection.tditrain.com:5433/NYCinspection
# Done.
# 87 rows affected.
# []

# %%
# %%sql
#
# --checking the total number of unique restaurants in "valid zip codes" - 19172
#
# select sum(camis_per_zip) from number_of_camis
# Out:
#  * postgresql://docker:***@nycinspection.tditrain.com:5433/NYCinspection
# 1 rows affected.
# [(Decimal('19172'),)]

# %%
# %%sql
#
# -- creating 'q2_temp' table by joining 'latest' and 'no_nulls' tables
#
# DROP TABLE IF EXISTS q2_temp;
#
# Create temporary table q2_temp as
#
# With latest as
#     (select camis as camis_latest, max(inspdate) as inspdate_latest
#      from filtered
#      group by camis)
# select camis, inspdate, max(zipcode) as zipcode, max(score) as score
# from latest join filtered on camis = camis_latest and inspdate = inspdate_latest
# group by camis, inspdate
# order by zipcode;
# Out:
#  * postgresql://docker:***@nycinspection.tditrain.com:5433/NYCinspection
# Done.
# 24361 rows affected.
# []

# %%
# %%sql
#
# -- getting the requested columns from the
#
# select zipcode, avg(score), count(distinct camis)
# from q2_temp
# group by zipcode
# having count(distinct camis) > 100
# order by avg;
# Out:
#  * postgresql://docker:***@nycinspection.tditrain.com:5433/NYCinspection
# 87 rows affected.
# [('10451', Decimal('9.1428571428571429'), 154),
#  ('10001', Decimal('9.1494949494949495'), 495),
#  ('11430', Decimal('9.6896551724137931'), 145),
#  ('11236', Decimal('9.8301886792452830'), 106),
#  ('10472', Decimal('10.1308411214953271'), 107),
#  ('11234', Decimal('10.1862068965517241'), 145),
#  ('11217', Decimal('10.3455284552845528'), 246),
#  ('10306', Decimal('10.5333333333333333'), 105),
#  ('11368', Decimal('10.5357142857142857'), 280),
#  ('10462', Decimal('10.5379310344827586'), 145),
#  ('11231', Decimal('10.5657894736842105'), 152),
#  ('11237', Decimal('10.6000000000000000'), 175),
#  ('10461', Decimal('10.6778523489932886'), 149),
#  ('11209', Decimal('10.6916996047430830'), 253),
#  ('10019', Decimal('10.7608024691358025'), 648),
#  ('11201', Decimal('10.7687687687687688'), 333),
#  ('11105', Decimal('10.7731092436974790'), 119),
#  ('10065', Decimal('10.9041916167664671'), 167),
#  ('11435', Decimal('10.9223300970873786'), 103),
#  ('10463', Decimal('10.9682539682539683'), 126),
#  ('10022', Decimal('10.9746300211416490'), 473),
#  ('10458', Decimal('11.0000000000000000'), 188),
#  ('10023', Decimal('11.0208333333333333'), 192),
#  ('10468', Decimal('11.0490196078431373'), 102),
#  ('10004', Decimal('11.0708661417322835'), 127),
#  ('11207', Decimal('11.1015625000000000'), 128),
#  ('10007', Decimal('11.1145038167938931'), 131),
#  ('10036', Decimal('11.1376936316695353'), 581),
#  ('11232', Decimal('11.1415094339622642'), 106),
#  ('11222', Decimal('11.1459459459459459'), 185),
#  ('11361', Decimal('11.1607142857142857'), 112),
#  ('11238', Decimal('11.2532751091703057'), 229),
#  ('11204', Decimal('11.2583333333333333'), 120),
#  ('11215', Decimal('11.3027777777777778'), 360),
#  ('11385', Decimal('11.3045267489711934'), 243),
#  ('11106', Decimal('11.3181818181818182'), 154),
#  ('11103', Decimal('11.3383084577114428'), 201),
#  ('10027', Decimal('11.3481012658227848'), 158),
#  ('10467', Decimal('11.3975155279503106'), 161),
#  ('11101', Decimal('11.4043478260869565'), 230),
#  ('10017', Decimal('11.4093406593406593'), 364),
#  ('11218', Decimal('11.4507042253521127'), 142),
#  ('11432', Decimal('11.5405405405405405'), 185),
#  ('10010', Decimal('11.5439330543933054'), 239),
#  ('10028', Decimal('11.6113744075829384'), 211),
#  ('10038', Decimal('11.6172839506172840'), 162),
#  ('11226', Decimal('11.6262626262626263'), 198),
#  ('11373', Decimal('11.6392694063926941'), 219),
#  ('10024', Decimal('11.6820512820512821'), 195),
#  ('11230', Decimal('11.7128712871287129'), 101),
#  ('11221', Decimal('11.7358490566037736'), 106),
#  ('10011', Decimal('11.7573696145124717'), 441),
#  ('10014', Decimal('11.7669172932330827'), 399),
#  ('10012', Decimal('11.7746835443037975'), 395),
#  ('11375', Decimal('11.8000000000000000'), 190),
#  ('10018', Decimal('11.8369230769230769'), 325),
#  ('10009', Decimal('11.8580858085808581'), 303),
#  ('11206', Decimal('11.8652482269503546'), 141),
#  ('10003', Decimal('11.9513677811550152'), 658),
#  ('11358', Decimal('11.9635036496350365'), 137),
#  ('11219', Decimal('11.9801980198019802'), 101),
#  ('10016', Decimal('11.9850746268656716'), 402),
#  ('11208', Decimal('11.9911504424778761'), 113),
#  ('10025', Decimal('12.0043668122270742'), 229),
#  ('10002', Decimal('12.0066079295154185'), 454),
#  ('10029', Decimal('12.1151832460732984'), 191),
#  ('10314', Decimal('12.1153846153846154'), 182),
#  ('11205', Decimal('12.1875000000000000'), 144),
#  ('10013', Decimal('12.2521551724137931'), 464),
#  ('11223', Decimal('12.2752808988764045'), 178),
#  ('11203', Decimal('12.2814814814814815'), 135),
#  ('11216', Decimal('12.3207547169811321'), 159),
#  ('11214', Decimal('12.3714285714285714'), 175),
#  ('11211', Decimal('12.4022988505747126'), 348),
#  ('10128', Decimal('12.5732484076433121'), 157),
#  ('10021', Decimal('12.5906040268456376'), 149),
#  ('11229', Decimal('12.6884057971014493'), 138),
#  ('11249', Decimal('12.8367346938775510'), 147),
#  ('11372', Decimal('12.8576051779935275'), 309),
#  ('10032', Decimal('12.9130434782608696'), 115),
#  ('11354', Decimal('13.1104651162790698'), 344),
#  ('11377', Decimal('13.1116504854368932'), 206),
#  ('10033', Decimal('13.1327433628318584'), 113),
#  ('11235', Decimal('13.2906976744186047'), 172),
#  ('11220', Decimal('13.3344262295081967'), 305),
#  ('11104', Decimal('13.3727272727272727'), 110),
#  ('11355', Decimal('14.0213903743315508'), 187)]

# %%
# storing the resultant table from sql query in a python variable

score_by_zipcode = _

# %%
#score_by_zipcode = [("11201", 21.9, 333)] * 87

grader.score('sql__score_by_zipcode', score_by_zipcode)
# Out:
# ==================
# Your score: 1.0000
# ==================

# %% [markdown]
# ## Question 3: Score by borough

# %% [markdown]
# Return a list of tuples of the form:
#
#     (borough, mean score, number of restaurants)
#
# for each of the city's five boroughs. Use the latest score for each restaurant. Sort the list in ascending order by the mean score.
#
# **Hint:** You will have to perform a join with the `boroughs` table. The borough names should be reported in ALL CAPS.
#
# **Checkpoint:**
# - Total restaurants in valid boroughs: 24,350

# %%
# %%sql
#
# -- checking the total number of restaurants in valid boroughs - 24350
#
# With boro_counts as
#     (select boro, count(distinct camis)
#      from filtered
#      group by boro
#      order by boro)
# select sum(count) from boro_counts
# where boro != 0;
# Out:
#  * postgresql://docker:***@nycinspection.tditrain.com:5433/NYCinspection
# 1 rows affected.
# [(Decimal('24350'),)]

# %%
# %%sql
#
# -- creating 'q3_temp table' using 'new_boro' subquery to get the 'latest' score for every restaurant using latest inspdate
#
# DROP TABLE IF EXISTS q3_temp;
#
# Create temporary table q3_temp as
#
# with new_boro as
#     (select boro as boro_latest, camis as camis_latest, max(inspdate) as inspdate_latest
#      from filtered
#      where boro !=0
#      group by boro, camis)
# select max(boro) as boro, camis, inspdate, max(score) as score
# from new_boro join filtered on camis = camis_latest and inspdate = inspdate_latest
# group by boro, camis, inspdate
# order by boro;
# Out:
#  * postgresql://docker:***@nycinspection.tditrain.com:5433/NYCinspection
# Done.
# 24350 rows affected.
# []

# %%
# %%sql
#
# -- double checking the data in 'boroughs' table before joining it to 'q3_temp' table
#
# select * from boroughs limit 10;
# Out:
#  * postgresql://docker:***@nycinspection.tditrain.com:5433/NYCinspection
# 5 rows affected.
# [(1, 'MANHATTAN'),
#  (2, 'THE BRONX'),
#  (3, 'BROOKLYN'),
#  (4, 'QUEENS'),
#  (5, 'STATEN ISLAND')]

# %%
# %%sql
#
# -- selecting the requested columns from final table by joining 'q3_temp' and 'boroughs' tables to get the boro 'name'
#
# select boroughs.name, avg(score), count(distinct camis)
# from q3_temp join boroughs on q3_temp.boro = boroughs.id
# group by boroughs.name
# order by avg;
# Out:
#  * postgresql://docker:***@nycinspection.tditrain.com:5433/NYCinspection
# 5 rows affected.
# [('THE BRONX', Decimal('10.7768522577816747'), 2281),
#  ('MANHATTAN', Decimal('11.4896370437771712'), 9891),
#  ('BROOKLYN', Decimal('11.5968541631048042'), 5849),
#  ('QUEENS', Decimal('11.8225955325826103'), 5417),
#  ('STATEN ISLAND', Decimal('11.8991228070175439'), 912)]

# %%
# saving sql table obtained as output in a dataframe

score_by_borough = _

# %%
#score_by_borough = [("MANHATTAN", 11.48963704377717, 9891)] * 5

grader.score('sql__score_by_borough', score_by_borough)
# Out:
# ==================
# Your score: 1.0000
# ==================

# %% [markdown]
# ## Question 4: Violations by cuisine

# %% [markdown]
# We want to look at violations themselves now.  We'll need to think more carefully about what we're measuring, since most restaurants have many inspections with possibly multiple violations per inspection, or long stretches of inspections with no violations.
#
# There are many ways to deal with this normalization issue, but we'll go with a fairly straightforward one: dividing the number of violations by the length of time (in years) the restaurant has been open.  As a proxy for the length, we'll look at the difference between the oldest and newest inspection date, treating anything less than 30 days as 30 days (to account for those that were only inspected once, we'll assume everything was open for at least a month).
#
# Since there are so many restaurants, we'll group them by cuisine and do a weighted average by computing
#
#     (total violations for a cuisine) / (total restaurant-years for that cuisine)
#
# Return a list of 75 tuples of the form
#
#     (cuisine name, reports per restaurant-year)
#
# for cuisines with at least 100 violations total, ordered by increasing number of reports per restaurant-year
#
# **Note:** This isn't the only way to normalize things.  How would other ways affect the computation?  If you similarly wanted to compute an average score by cuisine, how might you go about doing that?
#
# **Checkpoint:**
# - Total entries from valid cuisines: 522,410

# %%
# %%sql
#
# -- checking the data in the 'cuisine' table
#
# select * from cuisine
# order by cuisinecode;
# Out:
#  * postgresql://docker:***@nycinspection.tditrain.com:5433/NYCinspection
# 85 rows affected.
# [(0, 'Not Listed/Not Applicable'),
#  (1, 'Afghan'),
#  (2, 'African'),
#  (3, 'American '),
#  (4, 'Armenian'),
#  (5, 'Asian'),
#  (6, 'Australian'),
#  (7, 'Bagels/Pretzels'),
#  (8, 'Bakery'),
#  (9, 'Bangladeshi'),
#  (10, 'Barbecue'),
#  (11, 'Basque'),
#  (12, 'Bottled beverages, including water, sodas, juices, etc.'),
#  (13, 'Brazilian'),
#  (14, 'Café/Coffee/Tea'),
#  (15, 'Cajun'),
#  (16, 'Californian'),
#  (17, 'Caribbean'),
#  (18, 'Chicken'),
#  (19, 'Chilean'),
#  (20, 'Chinese'),
#  (21, 'Chinese/Cuban'),
#  (22, 'Chinese/Japanese'),
#  (23, 'Continental'),
#  (24, 'Creole'),
#  (25, 'Creole/Cajun'),
#  (26, 'Czech'),
#  (27, 'Delicatessen'),
#  (28, 'Vietnamese/Cambodian/Malaysia'),
#  (29, 'Donuts'),
#  (30, 'Eastern European'),
#  (31, 'Egyptian'),
#  (32, 'English'),
#  (33, 'Ethiopian'),
#  (34, 'Filipino'),
#  (35, 'French'),
#  (36, 'Fruits/Vegetables'),
#  (37, 'German'),
#  (38, 'Greek'),
#  (39, 'Hamburgers'),
#  (40, 'Hawaiian'),
#  (41, 'Hotdogs'),
#  (42, 'Hotdogs/Pretzels'),
#  (43, 'Ice Cream, Gelato, Yogurt, Ices'),
#  (44, 'Indian'),
#  (45, 'Indonesian'),
#  (46, 'Iranian'),
#  (47, 'Irish'),
#  (48, 'Italian'),
#  (49, 'Japanese'),
#  (50, 'Jewish/Kosher'),
#  (51, 'Juice, Smoothies, Fruit Salads'),
#  (52, 'Korean'),
#  (53, 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)'),
#  (54, 'Mediterranean'),
#  (55, 'Mexican'),
#  (56, 'Middle Eastern'),
#  (57, 'Moroccan'),
#  (58, 'Nuts/Confectionary'),
#  (59, 'Pakistani'),
#  (60, 'Pancakes/Waffles'),
#  (61, 'Peruvian'),
#  (62, 'Pizza'),
#  (63, 'Pizza/Italian'),
#  (64, 'Polish'),
#  (65, 'Polynesian'),
#  (66, 'Portuguese'),
#  (67, 'Russian'),
#  (68, 'Salads'),
#  (69, 'Sandwiches'),
#  (70, 'Sandwiches/Salads/Mixed Buffet'),
#  (71, 'Scandinavian'),
#  (72, 'Seafood'),
#  (73, 'Soul Food'),
#  (74, 'Soups'),
#  (75, 'Soups & Sandwiches'),
#  (76, 'Southwestern'),
#  (77, 'Spanish'),
#  (78, 'Steak'),
#  (80, 'Tapas'),
#  (81, 'Tex-Mex'),
#  (82, 'Thai'),
#  (83, 'Turkish'),
#  (84, 'Vegetarian'),
#  (99, 'Other')]

# %%
# %%sql
#
# select count(*) from filtered
# where violcode is NULL
# Out:
#  * postgresql://docker:***@nycinspection.tditrain.com:5433/NYCinspection
# 1 rows affected.
# [(5705,)]

# %%
# %%sql
#
# select count(cuisinecode)
# from filtered;
# Out:
#  * postgresql://docker:***@nycinspection.tditrain.com:5433/NYCinspection
# 1 rows affected.
# [(522812,)]

# %%
# %%sql
#
# -- solution as a single query with multiple subqueries
#
# with tmp as (
#
#     select cuisinecode, camis,
#         CASE
#             WHEN extract(day from (max(inspdate)-min(inspdate)))/365.25 > 0.082191781
#             THEN extract(day from (max(inspdate)-min(inspdate)))/365.25
#             ELSE 0.082191781
#         END AS rest_years,
#         count(*) as viol_count
#     from filtered
#     group by cuisinecode, camis),
#
# tmp2 as (
#
#     select cuisinecode, sum(rest_years) as cuisine_years, sum(viol_count) as violations_count
#     from tmp
#     group by cuisinecode
#     having sum(viol_count) >= 100),
#
# final as (
#     select cuisine.codedesc as cuisine_name, tmp2.violations_count/tmp2.cuisine_years as reports_per_restaurant_year
#     from tmp2
#         join cuisine on tmp2.cuisinecode = cuisine.cuisinecode
#     order by reports_per_restaurant_year)
#
# select * from final;
# Out:
#  * postgresql://docker:***@nycinspection.tditrain.com:5433/NYCinspection
# 75 rows affected.
# [('Hotdogs/Pretzels', Decimal('4.2964360720691115')),
#  ('Soups & Sandwiches', Decimal('6.02164405012686491589')),
#  ('Donuts', Decimal('6.17101044413941573075')),
#  ('Ice Cream, Gelato, Yogurt, Ices', Decimal('6.34160778754890328652')),
#  ('Hotdogs', Decimal('6.45797417292003718521')),
#  ('Sandwiches', Decimal('6.66654697144133670751')),
#  ('Café/Coffee/Tea', Decimal('6.80178240025635901562')),
#  ('Bottled beverages, including water, sodas, juices, etc.', Decimal('7.15630360756380920232')),
#  ('Juice, Smoothies, Fruit Salads', Decimal('7.21125536679107368929')),
#  ('Not Listed/Not Applicable', Decimal('7.44829666620228050093')),
#  ('Hamburgers', Decimal('7.49449580699357881062')),
#  ('Sandwiches/Salads/Mixed Buffet', Decimal('7.58706456955660063000')),
#  ('Ethiopian', Decimal('8.60529115120951857225')),
#  ('Barbecue', Decimal('8.89153672683745595660')),
#  ('Other', Decimal('9.21535838906772730660')),
#  ('English', Decimal('9.39116980640852149921')),
#  ('Steak', Decimal('9.43870825889831710520')),
#  ('Cajun', Decimal('9.6174352633110270')),
#  ('American ', Decimal('9.78325018387496803358')),
#  ('Salads', Decimal('9.83064808115097710082')),
#  ('Irish', Decimal('10.04137245784748796632')),
#  ('Egyptian', Decimal('10.10998293716361225556')),
#  ('Pizza', Decimal('10.15932133677319004940')),
#  ('Czech', Decimal('10.18118466898954706328')),
#  ('Chicken', Decimal('10.19397206122354580508')),
#  ('Armenian', Decimal('10.23072321369251046335')),
#  ('Continental', Decimal('10.23649784253002008198')),
#  ('Bagels/Pretzels', Decimal('10.29080825958571385837')),
#  ('Greek', Decimal('10.37741269794575753014')),
#  ('Middle Eastern', Decimal('10.52909390408401376567')),
#  ('French', Decimal('10.60951616083142855473')),
#  ('Vegetarian', Decimal('10.63690152045828340027')),
#  ('Tex-Mex', Decimal('10.69200742971178103637')),
#  ('Scandinavian', Decimal('10.71726073257187869003')),
#  ('Southwestern', Decimal('10.75794365046142447716')),
#  ('Polish', Decimal('10.92098685039441061114')),
#  ('Bakery', Decimal('10.99013112709198881310')),
#  ('Italian', Decimal('10.99340168994785525814')),
#  ('Mediterranean', Decimal('11.04769147587900858980')),
#  ('Australian', Decimal('11.13833157585962707976')),
#  ('Russian', Decimal('11.21278790122791538987')),
#  ('Seafood', Decimal('11.23217186483674276617')),
#  ('Pizza/Italian', Decimal('11.23627806087051465592')),
#  ('Moroccan', Decimal('11.24081371762283610938')),
#  ('Jewish/Kosher', Decimal('11.25293535829845040248')),
#  ('Tapas', Decimal('11.31812816237969889079')),
#  ('Pancakes/Waffles', Decimal('11.4986627951402155')),
#  ('German', Decimal('11.50763747809316296472')),
#  ('Soul Food', Decimal('11.65303731303323073275')),
#  ('Turkish', Decimal('11.98696236058372056480')),
#  ('Mexican', Decimal('12.12618882055587833591')),
#  ('Caribbean', Decimal('12.13985283010603683258')),
#  ('Eastern European', Decimal('12.28574704301704052510')),
#  ('Afghan', Decimal('12.41050276049138549390')),
#  ('Japanese', Decimal('12.43008503522466685821')),
#  ('Delicatessen', Decimal('12.76716167041698132689')),
#  ('Brazilian', Decimal('12.84542193369241676121')),
#  ('Vietnamese/Cambodian/Malaysia', Decimal('12.96923135270909288128')),
#  ('Thai', Decimal('12.98017758726731075287')),
#  ('Filipino', Decimal('13.11319888558221991398')),
#  ('African', Decimal('13.14213737684804640883')),
#  ('Latin (Cuban, Dominican, Puerto Rican, South & Central American)', Decimal('13.20101247017061575855')),
#  ('Korean', Decimal('13.34807791921586290814')),
#  ('Chinese', Decimal('13.41029542951255795498')),
#  ('Spanish', Decimal('13.45365725766881858827')),
#  ('Indian', Decimal('13.47250930512475178038')),
#  ('Asian', Decimal('13.75571587518685507700')),
#  ('Indonesian', Decimal('13.77209172411751821171')),
#  ('Peruvian', Decimal('13.79534445592935909229')),
#  ('Bangladeshi', Decimal('14.24253483537707465339')),
#  ('Chinese/Cuban', Decimal('14.90323413038138756843')),
#  ('Pakistani', Decimal('15.04763761556423680091')),
#  ('Portuguese', Decimal('15.23765362648460418634')),
#  ('Chinese/Japanese', Decimal('15.72016272423093262022')),
#  ('Creole', Decimal('16.07604065631668265505'))]

# %%
# %%sql
#
# -- create a temp table with restaurant years for each restaurant
#
# DROP TABLE IF EXISTS q4_temp;
#
# Create temporary table q4_temp as
#
# select cuisinecode, camis,
#     CASE
#         WHEN extract(day from (max(inspdate)-min(inspdate)))/365.25 > 0.082191781
#         THEN extract(day from (max(inspdate)-min(inspdate)))/365.25
#         ELSE 0.082191781
#     END AS rest_years
# from filtered
# group by cuisinecode, camis;
# Out:
#  * postgresql://docker:***@nycinspection.tditrain.com:5433/NYCinspection
# Done.
# 24361 rows affected.
# []

# %%
# %%sql
#
# select * from q4_temp
# limit 10;
# Out:
#  * postgresql://docker:***@nycinspection.tditrain.com:5433/NYCinspection
# 10 rows affected.
# [(82, 41508109, Decimal('2.7049965776865161')),
#  (20, 41636680, Decimal('2.2203969883641342')),
#  (99, 50005295, Decimal('0.09856262833675564682')),
#  (14, 40827435, Decimal('2.8610540725530459')),
#  (20, 41693802, Decimal('1.2457221081451061')),
#  (14, 40908366, Decimal('2.7022587268993840')),
#  (3, 40401352, Decimal('2.9514031485284052')),
#  (3, 40376031, Decimal('2.4093086926762491')),
#  (63, 40544529, Decimal('2.9952087611225188')),
#  (43, 40550801, Decimal('2.6776180698151951'))]

# %%
# %%sql
#
# select * from q4_temp
# where camis = '41546465';
# Out:
#  * postgresql://docker:***@nycinspection.tditrain.com:5433/NYCinspection
# 1 rows affected.
# [(82, 41546465, Decimal('2.8692676249144422'))]

# %%
# %%sql
#
# -- create a temp table #2 with cuisine years for each cuisine
#
# DROP TABLE IF EXISTS q4_temp2;
#
# Create temporary table q4_temp2 as
#
# select cuisinecode, sum(rest_years) as cuisine_years
# from q4_temp
# group by cuisinecode
# order by cuisinecode;
# Out:
#  * postgresql://docker:***@nycinspection.tditrain.com:5433/NYCinspection
# Done.
# 84 rows affected.
# []

# %%
# %%sql
#
# -- test the data in the temp table #2
#
# select * from q4_temp2
# limit 10;
# Out:
#  * postgresql://docker:***@nycinspection.tditrain.com:5433/NYCinspection
# 10 rows affected.
# [(0, 40367946, Decimal('2.8939082819986311')),
#  (0, 41075261, Decimal('2.5270362765229295')),
#  (0, 41328214, Decimal('2.3545516769336071')),
#  (0, 41630612, Decimal('1.8726899383983573')),
#  (0, 41643851, Decimal('1.5523613963039014')),
#  (0, 41677131, Decimal('1.1772758384668036')),
#  (0, 41679004, Decimal('1.6262833675564682')),
#  (0, 41683579, Decimal('1.3305954825462012')),
#  (0, 41693684, Decimal('1.0266940451745380')),
#  (0, 41698202, Decimal('0.98015058179329226557'))]

# %%
# %%sql
#
# -- create a temp table #3 with number of violations for each cuisine
#
# DROP TABLE IF EXISTS q4_temp3;
#
# Create temporary table q4_temp3 as
#
# select cuisinecode, count(*) as violations_count
# from filtered
# group by cuisinecode
# having count(violcode) >= 100;
# Out:
#  * postgresql://docker:***@nycinspection.tditrain.com:5433/NYCinspection
# Done.
# 75 rows affected.
# []

# %%
# %%sql
#
# -- test the data in the temp table #3
#
# select * from q4_temp3;
# Out:
#  * postgresql://docker:***@nycinspection.tditrain.com:5433/NYCinspection
# 75 rows affected.
# [(71, 149),
#  (68, 559),
#  (51, 2694),
#  (80, 616),
#  (52, 6942),
#  (70, 3089),
#  (84, 1974),
#  (69, 6601),
#  (60, 412),
#  (22, 1310),
#  (59, 821),
#  (73, 1027),
#  (44, 8230),
#  (42, 164),
#  (82, 6879),
#  (43, 3731),
#  (9, 814),
#  (15, 181),
#  (26, 128),
#  (48, 25701),
#  (72, 3260),
#  (57, 282),
#  (81, 2840),
#  (61, 1898),
#  (77, 13176),
#  (30, 1486),
#  (21, 437),
#  (3, 126125),
#  (17, 16244),
#  (37, 853),
#  (28, 1837),
#  (5, 7660),
#  (56, 3249),
#  (54, 4158),
#  (29, 6370),
#  (4, 639),
#  (34, 567),
#  (0, 133),
#  (83, 1526),
#  (67, 2037),
#  (63, 10663),
#  (10, 805),
#  (35, 7450),
#  (45, 215),
#  (6, 250),
#  (39, 7707),
#  (31, 337),
#  (50, 7572),
#  (14, 14936),
#  (66, 268),
#  (13, 668),
#  (2, 1858),
#  (62, 25775),
#  (75, 587),
#  (99, 1920),
#  (41, 466),
#  (32, 336),
#  (53, 26072),
#  (7, 3669),
#  (38, 2543),
#  (12, 1032),
#  (78, 1792),
#  (24, 686),
#  (49, 18465),
#  (47, 4425),
#  (20, 60958),
#  (33, 299),
#  (1, 295),
#  (76, 206),
#  (18, 7439),
#  (64, 724),
#  (55, 18461),
#  (27, 9597),
#  (23, 994),
#  (8, 16141)]

# %%
# %%sql
#
# -- create a temp table #4 with number of violations for each cuisine
#
# DROP TABLE IF EXISTS q4_temp4;
#
# Create temporary table q4_temp4 as
#
#
# select cuisine.codedesc, q4_temp3.violations_count, q4_temp2.cuisine_years
# from q4_temp3 join cuisine on q4_temp3.cuisinecode = cuisine.cuisinecode
#               join q4_temp2 on q4_temp2.cuisinecode = q4_temp3.cuisinecode;
# Out:
#  * postgresql://docker:***@nycinspection.tditrain.com:5433/NYCinspection
# Done.
# 75 rows affected.
# []

# %%
# %%sql
#
# -- test the data in the temp table #4
#
# select * from q4_temp4
# limit 10;
# Out:
#  * postgresql://docker:***@nycinspection.tditrain.com:5433/NYCinspection
# 10 rows affected.
# [('Scandinavian', 149, Decimal('13.90280629705681040691')),
#  ('Salads', 559, Decimal('56.86298557180698159247')),
#  ('Juice, Smoothies, Fruit Salads', 2694, Decimal('373.58266528824914487354')),
#  ('Tapas', 616, Decimal('54.42596082694318964045')),
#  ('Korean', 6942, Decimal('520.07487834681519469714')),
#  ('Sandwiches/Salads/Mixed Buffet', 3089, Decimal('407.14033361396919908198')),
#  ('Vegetarian', 1974, Decimal('185.58035873542162888953')),
#  ('Sandwiches', 6601, Decimal('990.16777775329089676124')),
#  ('Pancakes/Waffles', 412, Decimal('35.8302532511978097')),
#  ('Chinese/Japanese', 1310, Decimal('83.33247072441410016708'))]

# %%
# %%sql
#
# select codedesc as cuisine_name,
#        violations_count/cuisine_years as reports_per_restaurant_year
# from q4_temp4
# order by reports_per_restaurant_year;
# Out:
#  * postgresql://docker:***@nycinspection.tditrain.com:5433/NYCinspection
# 75 rows affected.
# [('Hotdogs/Pretzels', Decimal('4.2964360720691115')),
#  ('Soups & Sandwiches', Decimal('6.02164405012686491589')),
#  ('Donuts', Decimal('6.17101044413941573075')),
#  ('Ice Cream, Gelato, Yogurt, Ices', Decimal('6.34160778754890328652')),
#  ('Hotdogs', Decimal('6.45797417292003718521')),
#  ('Sandwiches', Decimal('6.66654697144133670751')),
#  ('Café/Coffee/Tea', Decimal('6.80178240025635901562')),
#  ('Bottled beverages, including water, sodas, juices, etc.', Decimal('7.15630360756380920232')),
#  ('Juice, Smoothies, Fruit Salads', Decimal('7.21125536679107368929')),
#  ('Not Listed/Not Applicable', Decimal('7.44829666620228050093')),
#  ('Hamburgers', Decimal('7.49449580699357881062')),
#  ('Sandwiches/Salads/Mixed Buffet', Decimal('7.58706456955660063000')),
#  ('Ethiopian', Decimal('8.60529115120951857225')),
#  ('Barbecue', Decimal('8.89153672683745595660')),
#  ('Other', Decimal('9.21535838906772730660')),
#  ('English', Decimal('9.39116980640852149921')),
#  ('Steak', Decimal('9.43870825889831710520')),
#  ('Cajun', Decimal('9.6174352633110270')),
#  ('American ', Decimal('9.78325018387496803358')),
#  ('Salads', Decimal('9.83064808115097710082')),
#  ('Irish', Decimal('10.04137245784748796632')),
#  ('Egyptian', Decimal('10.10998293716361225556')),
#  ('Pizza', Decimal('10.15932133677319004940')),
#  ('Czech', Decimal('10.18118466898954706328')),
#  ('Chicken', Decimal('10.19397206122354580508')),
#  ('Armenian', Decimal('10.23072321369251046335')),
#  ('Continental', Decimal('10.23649784253002008198')),
#  ('Bagels/Pretzels', Decimal('10.29080825958571385837')),
#  ('Greek', Decimal('10.37741269794575753014')),
#  ('Middle Eastern', Decimal('10.52909390408401376567')),
#  ('French', Decimal('10.60951616083142855473')),
#  ('Vegetarian', Decimal('10.63690152045828340027')),
#  ('Tex-Mex', Decimal('10.69200742971178103637')),
#  ('Scandinavian', Decimal('10.71726073257187869003')),
#  ('Southwestern', Decimal('10.75794365046142447716')),
#  ('Polish', Decimal('10.92098685039441061114')),
#  ('Bakery', Decimal('10.99013112709198881310')),
#  ('Italian', Decimal('10.99340168994785525814')),
#  ('Mediterranean', Decimal('11.04769147587900858980')),
#  ('Australian', Decimal('11.13833157585962707976')),
#  ('Russian', Decimal('11.21278790122791538987')),
#  ('Seafood', Decimal('11.23217186483674276617')),
#  ('Pizza/Italian', Decimal('11.23627806087051465592')),
#  ('Moroccan', Decimal('11.24081371762283610938')),
#  ('Jewish/Kosher', Decimal('11.25293535829845040248')),
#  ('Tapas', Decimal('11.31812816237969889079')),
#  ('Pancakes/Waffles', Decimal('11.4986627951402155')),
#  ('German', Decimal('11.50763747809316296472')),
#  ('Soul Food', Decimal('11.65303731303323073275')),
#  ('Turkish', Decimal('11.98696236058372056480')),
#  ('Mexican', Decimal('12.12618882055587833591')),
#  ('Caribbean', Decimal('12.13985283010603683258')),
#  ('Eastern European', Decimal('12.28574704301704052510')),
#  ('Afghan', Decimal('12.41050276049138549390')),
#  ('Japanese', Decimal('12.43008503522466685821')),
#  ('Delicatessen', Decimal('12.76716167041698132689')),
#  ('Brazilian', Decimal('12.84542193369241676121')),
#  ('Vietnamese/Cambodian/Malaysia', Decimal('12.96923135270909288128')),
#  ('Thai', Decimal('12.98017758726731075287')),
#  ('Filipino', Decimal('13.11319888558221991398')),
#  ('African', Decimal('13.14213737684804640883')),
#  ('Latin (Cuban, Dominican, Puerto Rican, South & Central American)', Decimal('13.20101247017061575855')),
#  ('Korean', Decimal('13.34807791921586290814')),
#  ('Chinese', Decimal('13.41029542951255795498')),
#  ('Spanish', Decimal('13.45365725766881858827')),
#  ('Indian', Decimal('13.47250930512475178038')),
#  ('Asian', Decimal('13.75571587518685507700')),
#  ('Indonesian', Decimal('13.77209172411751821171')),
#  ('Peruvian', Decimal('13.79534445592935909229')),
#  ('Bangladeshi', Decimal('14.24253483537707465339')),
#  ('Chinese/Cuban', Decimal('14.90323413038138756843')),
#  ('Pakistani', Decimal('15.04763761556423680091')),
#  ('Portuguese', Decimal('15.23765362648460418634')),
#  ('Chinese/Japanese', Decimal('15.72016272423093262022')),
#  ('Creole', Decimal('16.07604065631668265505'))]

# %%
score_by_cuisine = _

# %%
#score_by_cuisine = [("French", 10.60953571066525)] * 75

grader.score('sql__score_by_cuisine', score_by_cuisine)
# Out:
# ==================
# Your score: 1.0000
# ==================

# %% [markdown]
# ## Question 5: Specific violations by cuisine

# %% [markdown]
# Which cuisines tend to have a disproportionate number of what which violations? Answering this question isn't easy because you have to think carefully about normalizations.
#
# 1. More popular cuisine categories will tend to have more violations just because they represent more restaurants.
# 2. Similarly, some violations are more common.  For example, knowing that "Equipment not easily movable or sealed to floor" is a common violation for Chinese restaurants is not particularly helpful when it is a common violation for all restaurants.
#
# The right quantity is to look at is the conditional probability of a specific type of violation given a specific cuisine type and divide it by the unconditional probability of the violation for the entire population. Taking this ratio gives the right answer.  Return the 20 highest ratios of the form:
#
#     (cuisine, violation, ratio, count)
#
# **Hint:**
# 1. You might want to check out this [Stack Overflow post](http://stackoverflow.com/questions/972877/calculate-frequency-using-sql).
# 2. The definition of a violation changes with time.  For example, 10A can mean two different things "Toilet facility not maintained ..." or "Vermin or other live animal present ..." when things were prior to 2003. To deal with this, you should limit your analysis to violation codes with end date after Jan 1, 2014. (This end date refers to the validity time ranges in `violations` table).
# 3. The ratios don't mean much when the number of violations of a given type and for a specific category are not large (why not?).  We chose 100 as our cutoff.  We include these categories in the statistics calculations, but do not report their values.
#
# **Checkpoint:**
# - Top 20 ratios mean: 2.360652529900757

# %%
# %%sql
#
# select * from violations
# limit 10;
# Out:
#  * postgresql://docker:***@nycinspection.tditrain.com:5433/NYCinspection
# 10 rows affected.
# [(datetime.datetime(1901, 1, 1, 0, 0), datetime.datetime(2003, 3, 23, 0, 0), 'Y', '01A', 'Current valid <a    onmouseover="ShowContent(\'P2\',\'01A\'); return true;"     href="javascript:ShowContent(\'P2\',\'01A\')">permit</A> , registration or other authorization to operate establishment not available.'),
#  (datetime.datetime(2003, 3, 24, 0, 0), datetime.datetime(2005, 2, 17, 0, 0), 'Y', '01A', 'Current valid <a    onmouseover="ShowContent(\'P2\',\'01A\'); return true;"     href="javascript:ShowContent(\'P2\',\'01A\')">permit</A> , registration or other authorization to operate establishment not available.'),
#  (datetime.datetime(2005, 2, 18, 0, 0), datetime.datetime(2007, 6, 30, 0, 0), 'Y', '01A', 'Current valid <a    onmouseover="ShowContent(\'P2\',\'01A\'); return true;"     href="javascript:ShowContent(\'P2\',\'01A\')">permit</A> , registration or other authorization to operate establishment not available.'),
#  (datetime.datetime(2007, 7, 1, 0, 0), datetime.datetime(2008, 6, 30, 0, 0), 'Y', '01A', 'Current valid permit, registration or other authorization to operate establishment not available.  Violations points are not assessed for Smoke Free Air Act, trans fat, calorie posting or permit and poster violations.'),
#  (datetime.datetime(2008, 7, 1, 0, 0), datetime.datetime(2009, 8, 1, 0, 0), 'Y', '01A', 'Current valid permit, registration or other authorization to operate establishment not available.  Violations points are not assessed for Smoke Free Air Act, trans fat, calorie posting or permit and poster violations.'),
#  (datetime.datetime(1901, 1, 1, 0, 0), datetime.datetime(2003, 3, 23, 0, 0), 'Y', '01B', 'Current valid permit, registration or other authorization to operate Temporary Food Service Establishment is not available.'),
#  (datetime.datetime(2003, 3, 24, 0, 0), datetime.datetime(2005, 2, 17, 0, 0), 'Y', '01B', 'Document issued by the Board, Commissioner or Department unlawfully reproduced or altered.'),
#  (datetime.datetime(2005, 2, 18, 0, 0), datetime.datetime(2007, 6, 30, 0, 0), 'Y', '01B', 'Document issued by the Board, Commissioner or Department unlawfully reproduced or altered.'),
#  (datetime.datetime(2007, 7, 1, 0, 0), datetime.datetime(2008, 6, 30, 0, 0), 'Y', '01B', 'Document issued by the Board, Commissioner or Department unlawfully reproduced or altered.'),
#  (datetime.datetime(2008, 7, 1, 0, 0), datetime.datetime(2009, 8, 1, 0, 0), 'Y', '01B', 'Document issued by the Board, Commissioner or Department unlawfully reproduced or altered.')]

# %%
# %%sql
#
# select * from violations
# where violationcode = '10A'
# limit 10;
# Out:
#  * postgresql://docker:***@nycinspection.tditrain.com:5433/NYCinspection
# 6 rows affected.
# [(datetime.datetime(1901, 1, 1, 0, 0), datetime.datetime(2003, 3, 23, 0, 0), 'N', '10A', '<a    onmouseover="ShowContent(\'V1\',\'10A\'); return true;"     href="javascript:ShowContent(\'V1\',\'10A\')">Vermin</a> or other live animal present in non-food area.'),
#  (datetime.datetime(2005, 2, 18, 0, 0), datetime.datetime(2007, 6, 30, 0, 0), 'N', '10A', 'Toilet facility not maintained and provided with toilet paper, waste receptacle and self-closing door.'),
#  (datetime.datetime(2007, 7, 1, 0, 0), datetime.datetime(2008, 6, 30, 0, 0), 'N', '10A', 'Toilet facility not maintained and provided with toilet paper, waste receptacle and self-closing door.'),
#  (datetime.datetime(2008, 7, 1, 0, 0), datetime.datetime(2009, 8, 1, 0, 0), 'N', '10A', 'Toilet facility not maintained and provided with toilet paper, waste receptacle and self-closing door.'),
#  (datetime.datetime(2009, 8, 2, 0, 0), datetime.datetime(2010, 7, 25, 0, 0), 'N', '10A', 'Toilet facility not maintained and provided with toilet paper, waste receptacle and self-closing door.'),
#  (datetime.datetime(2010, 7, 26, 0, 0), datetime.datetime(2099, 12, 31, 0, 0), 'N', '10A', 'Toilet facility not maintained and provided with toilet paper, waste receptacle and self-closing door.')]

# %%
# %%sql
#
# select count(*) from violations
# limit 10;
# Out:
#  * postgresql://docker:***@nycinspection.tditrain.com:5433/NYCinspection
# 1 rows affected.
# [(719,)]

# %%
# %%sql
#
# -- create a temp table #1 with the violations occured after Jan 1, 2014
#
# DROP TABLE IF EXISTS valid_violations;
#
# Create temporary table valid_violations as
#
# select * from violations
# where enddate > '2014-01-01';
# Out:
#  * postgresql://docker:***@nycinspection.tditrain.com:5433/NYCinspection
# Done.
# 112 rows affected.
# []

# %%
# %%sql
#
# select * from valid_violations;
# Out:
#  * postgresql://docker:***@nycinspection.tditrain.com:5433/NYCinspection
# 112 rows affected.
# [(datetime.datetime(2010, 7, 26, 0, 0), datetime.datetime(2099, 12, 31, 0, 0), 'Y', '02A', 'Food not cooked to required minimum temperature.'),
#  (datetime.datetime(2010, 7, 26, 0, 0), datetime.datetime(2099, 12, 31, 0, 0), 'Y', '02B', 'Hot food item not held at or above 140º F.'),
#  (datetime.datetime(2010, 7, 26, 0, 0), datetime.datetime(2099, 12, 31, 0, 0), 'Y', '02C', 'Hot food item that has been cooked and refrigerated is being held for service without first being reheated to 1 65º F or above within 2 hours.'),
#  (datetime.datetime(2010, 7, 26, 0, 0), datetime.datetime(2099, 12, 31, 0, 0), 'Y', '02D', 'Precooked potentially hazardous food from commercial food processing establishment that is supposed to be heated, but is not heated to 140º F within 2 hours.'),
#  (datetime.datetime(2010, 7, 26, 0, 0), datetime.datetime(2099, 12, 31, 0, 0), 'Y', '02E', 'Whole frozen poultry or poultry breasts, other than a single portion, is being cooked frozen or partially thawed.'),
#  (datetime.datetime(2010, 7, 26, 0, 0), datetime.datetime(2099, 12, 31, 0, 0), 'Y', '02F', 'Meat, fish or molluscan shellfish served raw or undercooked without prior notification to customer.'),
#  (datetime.datetime(2010, 7, 26, 0, 0), datetime.datetime(2099, 12, 31, 0, 0), 'Y', '02G', 'Cold food item held above 41º F (smoked fish and reduced oxygen packaged foods above 38 ºF) except during necessary preparation.'),
#  (datetime.datetime(2010, 7, 26, 0, 0), datetime.datetime(2099, 12, 31, 0, 0), 'Y', '02H', 'Food not cooled by an approved method whereby the internal product temperature is reduced from 140º F to 70º F or less within 2 hours, and from 70º F to 41º F or less within 4 additional hours.'),
#  (datetime.datetime(2010, 7, 26, 0, 0), datetime.datetime(2099, 12, 31, 0, 0), 'Y', '02I', 'Food prepared from ingredients at ambient temperature not cooled to 41º F or below within 4 hours.'),
#  (datetime.datetime(2010, 7, 26, 0, 0), datetime.datetime(2099, 12, 31, 0, 0), 'Y', '02J', 'Reduced oxygen packaged (ROP) foods not cooled by an approved method whereby the internal food temperature is reduced to 38º F within two hours of cooking and if necessary further cooled to a temperature of 34º F within six hours of reaching 38º F.'),
#  (datetime.datetime(2010, 7, 26, 0, 0), datetime.datetime(2099, 12, 31, 0, 0), 'Y', '03A', 'Food from unapproved or unknown source or home canned. Reduced oxygen packaged (ROP) fish not frozen before processing; or ROP foods prepared on premises transported to another site.'),
#  (datetime.datetime(2010, 7, 26, 0, 0), datetime.datetime(2099, 12, 31, 0, 0), 'Y', '03B', 'Shellfish not from approved source, improperly tagged/labeled; tags not retained for 90 days.'),
#  (datetime.datetime(2010, 7, 26, 0, 0), datetime.datetime(2099, 12, 31, 0, 0), 'Y', '03C', 'Eggs found dirty/cracked; liquid, frozen or powdered eggs not pasteurized.'),
#  (datetime.datetime(2010, 7, 26, 0, 0), datetime.datetime(2099, 12, 31, 0, 0), 'Y', '03D', 'Canned food product observed swollen, leaking or rusted, and not segregated from other consumable food items .'),
#  (datetime.datetime(2010, 7, 26, 0, 0), datetime.datetime(2099, 12, 31, 0, 0), 'Y', '03E', 'Potable water supply inadequate. Water or ice not potable or from unapproved source.  Cross connection in potable water supply system observed.'),
#  (datetime.datetime(2010, 7, 26, 0, 0), datetime.datetime(2099, 12, 31, 0, 0), 'Y', '03F', 'Unpasteurized milk or milk product present.'),
#  (datetime.datetime(2010, 7, 26, 0, 0), datetime.datetime(2099, 12, 31, 0, 0), 'Y', '03G', 'Raw food not properly washed prior to serving.'),
#  (datetime.datetime(2010, 7, 26, 0, 0), datetime.datetime(2099, 12, 31, 0, 0), 'Y', '04A', 'Food Protection Certificate not held by supervisor of food operations.'),
#  (datetime.datetime(2010, 7, 26, 0, 0), datetime.datetime(2099, 12, 31, 0, 0), 'Y', '04B', 'Food worker prepares food or handles utensil when ill with a disease transmissible by food, or have exposed infected cut or burn on hand.'),
#  (datetime.datetime(2010, 7, 26, 0, 0), datetime.datetime(2099, 12, 31, 0, 0), 'Y', '04C', 'Food worker does not use proper utensil to eliminate bare hand contact with food that will not receive adequate additional heat treatment.'),
#  (datetime.datetime(2010, 7, 26, 0, 0), datetime.datetime(2099, 12, 31, 0, 0), 'Y', '04D', 'Food worker does not wash hands thoroughly after using the toilet, coughing, sneezing, smoking, eating, preparing raw foods or otherwise contaminating hands.'),
#  (datetime.datetime(2010, 7, 26, 0, 0), datetime.datetime(2099, 12, 31, 0, 0), 'Y', '04E', 'Toxic chemical improperly labeled, stored or used such that food contamination may occur.'),
#  (datetime.datetime(2010, 7, 26, 0, 0), datetime.datetime(2099, 12, 31, 0, 0), 'Y', '04F', 'Food, food preparation area, food storage area, area used by employees or patrons, contaminated by sewage or liquid waste.'),
#  (datetime.datetime(2010, 7, 26, 0, 0), datetime.datetime(2099, 12, 31, 0, 0), 'Y', '04G', 'Unprotected potentially hazardous food re-served.'),
#  (datetime.datetime(2010, 7, 26, 0, 0), datetime.datetime(2099, 12, 31, 0, 0), 'Y', '04H', 'Raw, cooked or prepared food is adulterated, contaminated, cross-contaminated, or not discarded in accordance with HACCP plan.'),
#  (datetime.datetime(2010, 7, 26, 0, 0), datetime.datetime(2099, 12, 31, 0, 0), 'Y', '04I', 'Unprotected food re-served.'),
#  (datetime.datetime(2010, 7, 26, 0, 0), datetime.datetime(2099, 12, 31, 0, 0), 'Y', '04J', 'Appropriately scaled metal stem-type thermometer or thermocouple not provided or used to evaluate temperatures of potentially hazardous foods during cooking, cooling, reheating and holding.'),
#  (datetime.datetime(2010, 7, 26, 0, 0), datetime.datetime(2099, 12, 31, 0, 0), 'Y', '04K', "Evidence of rats or live rats present in facility's food and/or non-food areas."),
#  (datetime.datetime(2010, 7, 26, 0, 0), datetime.datetime(2099, 12, 31, 0, 0), 'Y', '04L', "Evidence of mice or live mice present in facility's food and/or non-food areas."),
#  (datetime.datetime(2010, 7, 26, 0, 0), datetime.datetime(2099, 12, 31, 0, 0), 'Y', '04M', "Live roaches present in facility's food and/or non-food areas."),
#  (datetime.datetime(2010, 7, 26, 0, 0), datetime.datetime(2099, 12, 31, 0, 0), 'Y', '04N', 'Filth flies or food/refuse/sewage-associated (FRSA) flies present in facility’s food and/or non-food areas. Filth flies include house flies, little house flies, blow flies, bottle flies and flesh flies. Food/refuse/sewage-associated flies include fruit flies, drain flies and Phorid flies.'),
#  (datetime.datetime(2010, 7, 26, 0, 0), datetime.datetime(2099, 12, 31, 0, 0), 'Y', '04O', "Live animals other than fish in tank or service animal present in facility's food and/or non-food areas."),
#  (datetime.datetime(2010, 7, 26, 0, 0), datetime.datetime(2099, 12, 31, 0, 0), 'Y', '05A', 'Sewage disposal system improper or unapproved.'),
#  (datetime.datetime(2010, 7, 26, 0, 0), datetime.datetime(2099, 12, 31, 0, 0), 'Y', '05B', 'Harmful, noxious gas or vapor detected. CO ~1 3 ppm.'),
#  (datetime.datetime(2010, 7, 26, 0, 0), datetime.datetime(2099, 12, 31, 0, 0), 'Y', '05C', 'Food contact surface improperly constructed or located. Unacceptable material used.'),
#  (datetime.datetime(2010, 7, 26, 0, 0), datetime.datetime(2099, 12, 31, 0, 0), 'Y', '05D', 'Hand washing facility not provided in or near food preparation area and toilet room. Hot and cold running water at adequate pressure to enable cleanliness of employees not provided at facility. Soap and an acceptable hand-drying device not provided.'),
#  (datetime.datetime(2010, 7, 26, 0, 0), datetime.datetime(2099, 12, 31, 0, 0), 'Y', '05E', 'Toilet facility not provided for employees or for patrons when required.'),
#  (datetime.datetime(2010, 7, 26, 0, 0), datetime.datetime(2099, 12, 31, 0, 0), 'Y', '05F', 'Insufficient or no refrigerated or hot holding equipment to keep potentially hazardous foods at required temperatures.'),
#  (datetime.datetime(2010, 7, 26, 0, 0), datetime.datetime(2099, 12, 31, 0, 0), 'Y', '05G', 'Properly enclosed service/maintenance area not provided.'),
#  (datetime.datetime(2010, 7, 26, 0, 0), datetime.datetime(2099, 12, 31, 0, 0), 'Y', '05H', 'No facilities available to wash, rinse and sanitize utensils and/or equipment.'),
#  (datetime.datetime(2010, 7, 26, 0, 0), datetime.datetime(2099, 12, 31, 0, 0), 'Y', '05I', 'Refrigeration used to implement HACCP plan not equipped with an electronic system that continuously monitors time and temperature.'),
#  (datetime.datetime(2010, 7, 26, 0, 0), datetime.datetime(2099, 12, 31, 0, 0), 'Y', '06A', 'Personal cleanliness inadequate. Outer garment soiled with possible contaminant.  Effective hair restraint not worn in an area where food is prepared.'),
#  (datetime.datetime(2010, 7, 26, 0, 0), datetime.datetime(2099, 12, 31, 0, 0), 'Y', '06B', 'Tobacco use, eating, or drinking from open container in food preparation, food storage or dishwashing area observed.'),
#  (datetime.datetime(2010, 7, 26, 0, 0), datetime.datetime(2099, 12, 31, 0, 0), 'Y', '06C', 'Food not protected from potential source of contamination during storage, preparation, transportation, display or service.'),
#  (datetime.datetime(2010, 7, 26, 0, 0), datetime.datetime(2099, 12, 31, 0, 0), 'Y', '06D', 'Food contact surface not properly washed, rinsed and sanitized after each use and following any activity when contamination may have occurred.'),
#  (datetime.datetime(2010, 7, 26, 0, 0), datetime.datetime(2099, 12, 31, 0, 0), 'Y', '06E', 'Sanitized equipment or utensil, including in-use food dispensing utensil, improperly used or stored.'),
#  (datetime.datetime(2010, 7, 26, 0, 0), datetime.datetime(2099, 12, 31, 0, 0), 'Y', '06F', 'Wiping cloths soiled or not stored in sanitizing solution.'),
#  (datetime.datetime(2010, 7, 26, 0, 0), datetime.datetime(2099, 12, 31, 0, 0), 'Y', '06G', 'HACCP plan not approved or approved HACCP plan not maintained on premises.'),
#  (datetime.datetime(2010, 7, 26, 0, 0), datetime.datetime(2099, 12, 31, 0, 0), 'Y', '06H', 'Records and logs not maintained to demonstrate that HACCP plan has been properly implemented.'),
#  (datetime.datetime(2010, 7, 26, 0, 0), datetime.datetime(2099, 12, 31, 0, 0), 'Y', '06I', 'Food not labeled in accordance with HACCP plan.'),
#  (datetime.datetime(2010, 7, 26, 0, 0), datetime.datetime(2099, 12, 31, 0, 0), 'Y', '07A', 'Duties of an officer of the Department interfered with or obstructed.'),
#  (datetime.datetime(2010, 7, 26, 0, 0), datetime.datetime(2099, 12, 31, 0, 0), 'N', '08A', 'Facility not vermin proof. Harborage or conditions conducive to attracting vermin to the premises and/or allowing vermin to exist.'),
#  (datetime.datetime(2010, 7, 26, 0, 0), datetime.datetime(2099, 12, 31, 0, 0), 'N', '08B', 'Covered garbage receptacle not provided or inadequate, except that garbage receptacle may be uncovered during active use. Garbage storage area not properly constructed or maintained; grinder or compactor dirty.'),
#  (datetime.datetime(2010, 7, 26, 0, 0), datetime.datetime(2099, 12, 31, 0, 0), 'N', '08C', 'Pesticide use not in accordance with label or applicable laws. Prohibited chemical used/stored. Open bait station used.'),
#  (datetime.datetime(2010, 7, 26, 0, 0), datetime.datetime(2099, 12, 31, 0, 0), 'N', '09A', 'Canned food product observed dented and not segregated from other consumable food items.'),
#  (datetime.datetime(2010, 7, 26, 0, 0), datetime.datetime(2099, 12, 31, 0, 0), 'N', '09B', 'Thawing procedures improper.'),
#  (datetime.datetime(2010, 7, 26, 0, 0), datetime.datetime(2099, 12, 31, 0, 0), 'N', '09C', 'Food contact surface not properly maintained.'),
#  (datetime.datetime(2010, 7, 26, 0, 0), datetime.datetime(2099, 12, 31, 0, 0), 'N', '10A', 'Toilet facility not maintained and provided with toilet paper, waste receptacle and self-closing door.'),
#  (datetime.datetime(2010, 7, 26, 0, 0), datetime.datetime(2099, 12, 31, 0, 0), 'N', '10B', 'Plumbing not properly installed or maintained; anti-siphonage or backflow prevention device not provided where required; equipment or floor not properly drained; sewage disposal system in disrepair or not functioning properly.'),
#  (datetime.datetime(2010, 7, 26, 0, 0), datetime.datetime(2099, 12, 31, 0, 0), 'N', '10C', 'Lighting inadequate; permanent lighting not provided in food preparation areas, ware washing areas, and storage rooms.'),
#  (datetime.datetime(2010, 7, 26, 0, 0), datetime.datetime(2099, 12, 31, 0, 0), 'N', '10D', 'Mechanical or natural ventilation system not provided, improperly installed, in disrepair and/or fails to prevent excessive build-up of grease, heat, steam condensation vapors, odors, smoke, and fumes.'),
#  (datetime.datetime(2010, 7, 26, 0, 0), datetime.datetime(2099, 12, 31, 0, 0), 'N', '10E', 'Accurate thermometer not provided in refrigerated or hot holding equipment.'),
#  (datetime.datetime(2010, 7, 26, 0, 0), datetime.datetime(2099, 12, 31, 0, 0), 'N', '10F', 'Non-food contact surface improperly constructed. Unacceptable material used. Non-food contact surface or equipment improperly maintained and/or not properly sealed, raised, spaced or movable to allow accessibility for cleaning on all sides, above and underneath the unit.'),
#  (datetime.datetime(2010, 7, 26, 0, 0), datetime.datetime(2099, 12, 31, 0, 0), 'N', '10G', 'Food service operation occurring in room used as living or sleeping quarters.'),
#  (datetime.datetime(2010, 7, 26, 0, 0), datetime.datetime(2099, 12, 31, 0, 0), 'N', '10H', 'Proper sanitization not provided for utensil ware washing operation.'),
#  (datetime.datetime(2010, 7, 26, 0, 0), datetime.datetime(2099, 12, 31, 0, 0), 'N', '10I', 'Single service item reused, improperly stored, dispensed; not used when required.'),
#  (datetime.datetime(2010, 7, 26, 0, 0), datetime.datetime(2099, 12, 31, 0, 0), 'N', '10J', '""Wash hands” sign not posted at hand wash facility.'),
#  (datetime.datetime(2010, 7, 26, 0, 0), datetime.datetime(2099, 12, 31, 0, 0), 'N', '15A', 'Tobacco vending machine present where prohibited.'),
#  (datetime.datetime(2010, 7, 26, 0, 0), datetime.datetime(2099, 12, 31, 0, 0), 'N', '15B', 'Tobacco vending machine placed less than 25 feet from entrance to premises.'),
#  (datetime.datetime(2010, 7, 26, 0, 0), datetime.datetime(2099, 12, 31, 0, 0), 'N', '15C', 'Tobacco vending machine not visible to the operator, employee or agent.'),
#  (datetime.datetime(2010, 7, 26, 0, 0), datetime.datetime(2099, 12, 31, 0, 0), 'N', '15D', 'Durable sign with license number, expiration date, and address and phone number not posted.'),
#  (datetime.datetime(2010, 7, 26, 0, 0), datetime.datetime(2099, 12, 31, 0, 0), 'N', '15E', 'Out-of package sale of tobacco products observed.'),
#  (datetime.datetime(2010, 7, 26, 0, 0), datetime.datetime(2099, 12, 31, 0, 0), 'N', '15F', 'Employee under the age of 18 selling tobacco products without direct supervision of an adult retail dealer or dealer.'),
#  (datetime.datetime(2010, 7, 26, 0, 0), datetime.datetime(2099, 12, 31, 0, 0), 'N', '15G', 'Sale to minor observed.'),
#  (datetime.datetime(2010, 7, 26, 0, 0), datetime.datetime(2099, 12, 31, 0, 0), 'N', '15H', 'Sign prohibiting sale of tobacco products to minors not conspicuously posted.'),
#  (datetime.datetime(2010, 7, 26, 0, 0), datetime.datetime(2099, 12, 31, 0, 0), 'N', '15I', '""No Smoking” and/or \'Smoking Permitted” sign not conspicuously posted. Health warning not present on \'Smoking Permitted”'),
#  (datetime.datetime(2010, 7, 26, 0, 0), datetime.datetime(2099, 12, 31, 0, 0), 'N', '15J', 'Ashtray present in smoke-free area.'),
#  (datetime.datetime(2010, 7, 26, 0, 0), datetime.datetime(2099, 12, 31, 0, 0), 'N', '15K', 'Operator failed to make good faith effort to inform smokers of the Smoke-free Act prohibition of smoking.'),
#  (datetime.datetime(2010, 7, 26, 0, 0), datetime.datetime(2099, 12, 31, 0, 0), 'N', '15L', 'Smoke free workplace smoking policy inadequate, not posted, not provided to employees.'),
#  (datetime.datetime(2010, 7, 26, 0, 0), datetime.datetime(2099, 12, 31, 0, 0), 'N', '15M', 'Use of tobacco product on school premises (at or below the 12th grade level) observed.'),
#  (datetime.datetime(2010, 7, 26, 0, 0), datetime.datetime(2099, 12, 31, 0, 0), 'N', '15N', 'Smoking permitted and/or allowed in smoking prohibited area under the operator’s control.'),
#  (datetime.datetime(2010, 7, 26, 0, 0), datetime.datetime(2099, 12, 31, 0, 0), 'N', '15O', 'Sale of herbal cigarettes to minors observed.'),
#  (datetime.datetime(2010, 7, 26, 0, 0), datetime.datetime(2099, 12, 31, 0, 0), 'N', '15P', 'No tobacco health warning and smoking cessation sign(s) are posted.'),
#  (datetime.datetime(2010, 7, 26, 0, 0), datetime.datetime(2099, 12, 31, 0, 0), 'N', '15Q', 'Tobacco health warning and smoking cessation sign(s) are obstructed and/or not prominently displayed.'),
#  (datetime.datetime(2010, 7, 26, 0, 0), datetime.datetime(2099, 12, 31, 0, 0), 'N', '15R', 'No large tobacco health warning and smoking cessation sign is posted where tobacco products are displayed; small sign(s) are not posted at each register or place of payment.'),
#  (datetime.datetime(2010, 7, 26, 0, 0), datetime.datetime(2099, 12, 31, 0, 0), 'N', '15S', 'Flavored tobacco products sold or offered for sale.'),
#  (datetime.datetime(2010, 7, 26, 0, 0), datetime.datetime(2099, 12, 31, 0, 0), 'N', '15T', 'Original label for tobacco products sold or offered for sale.'),
#  (datetime.datetime(2010, 7, 26, 0, 0), datetime.datetime(2099, 12, 31, 0, 0), 'N', '22A', 'Nuisance created or allowed to exist. Facility not free from unsafe, hazardous, offensive or annoying conditions.'),
#  (datetime.datetime(2010, 7, 26, 0, 0), datetime.datetime(2099, 12, 31, 0, 0), 'N', '16A', 'A food containing artificial trans fat, with 0.5 grams or more of trans fat per serving, is being stored, distributed, held for service, used in preparation of a menu item, or served.'),
#  (datetime.datetime(2010, 7, 26, 0, 0), datetime.datetime(2099, 12, 31, 0, 0), 'N', '16B', 'The original nutritional fact labels and/or ingredient label for a cooking oil, shortening or margarine or food item sold in bulk, or acceptable manufacturer’s documentation not maintained on site.'),
#  (datetime.datetime(2010, 7, 26, 0, 0), datetime.datetime(2099, 12, 31, 0, 0), 'N', '16C', 'Caloric content not posted on menus, menu boards or food tags, in a food service establishment that is 1 of 15 or more outlets operating the same typ ... (62 characters truncated) ...  as a franchise or doing business under the same name, for each menu item that is served in portions, the size and content of which are standardized.'),
#  (datetime.datetime(2010, 7, 26, 0, 0), datetime.datetime(2099, 12, 31, 0, 0), 'N', '16D', 'Posted caloric content on the menu(s), menu board(s), food tag(s) or stanchions adjacent to menu boards for drive-through windows deficient, in that the size and/or font for posted calories is not as prominent as the name of the menu item or its price.'),
#  (datetime.datetime(2010, 7, 26, 0, 0), datetime.datetime(2099, 12, 31, 0, 0), 'N', '16E', 'Caloric content range (minimum to maximum) not posted on menus and or menu boards for each flavor, variety and size of each menu item that is offered for sale in different flavors, varieties and sizes.'),
#  (datetime.datetime(2010, 7, 26, 0, 0), datetime.datetime(2099, 12, 31, 0, 0), 'N', '16F', 'Specific caloric content or range thereof not posted on menus, menu boards or food tags for each menu item offered as a combination meal with multiple options that are listed as single items.'),
#  (datetime.datetime(2010, 7, 26, 0, 0), datetime.datetime(2099, 12, 31, 0, 0), 'N', '18A', 'Current valid permit, registration or other authorization to operate establishment not available.'),
#  (datetime.datetime(2010, 7, 26, 0, 0), datetime.datetime(2099, 12, 31, 0, 0), 'N', '18B', 'Document issued by the Board of Health, Commissioner or Department unlawfully reproduced or altered.'),
#  (datetime.datetime(2010, 7, 26, 0, 0), datetime.datetime(2099, 12, 31, 0, 0), 'N', '18C', 'Notice of the Department of Board of Health mutilated, obstructed, or removed.'),
#  (datetime.datetime(2010, 7, 26, 0, 0), datetime.datetime(2099, 12, 31, 0, 0), 'N', '18D', 'Failure to comply with an Order of the Board of Health, Commissioner, or Department.'),
#  (datetime.datetime(2010, 7, 26, 0, 0), datetime.datetime(2099, 12, 31, 0, 0), 'N', '18E', 'Failure to report occurrences of suspected food borne illness to the Department.'),
#  (datetime.datetime(2010, 7, 26, 0, 0), datetime.datetime(2099, 12, 31, 0, 0), 'N', '18F', 'Permit not conspicuously displayed.'),
#  (datetime.datetime(2010, 7, 26, 0, 0), datetime.datetime(2099, 12, 31, 0, 0), 'N', '18G', 'Manufacture of frozen dessert not authorized on Food Service Establishment permit.'),
#  (datetime.datetime(2010, 7, 26, 0, 0), datetime.datetime(2099, 12, 31, 0, 0), 'N', '18H', 'Failure of event sponsor to exclude vendor without a current valid permit or registration.'),
#  (datetime.datetime(2010, 7, 26, 0, 0), datetime.datetime(2099, 12, 31, 0, 0), 'N', '20A', 'Food allergy information poster not conspicuously posted where food is being prepared or processed by food workers.'),
#  (datetime.datetime(2010, 7, 26, 0, 0), datetime.datetime(2099, 12, 31, 0, 0), 'N', '20B', 'Food allergy information poster not posted in language understood by all food workers.'),
#  (datetime.datetime(2010, 7, 26, 0, 0), datetime.datetime(2099, 12, 31, 0, 0), 'N', '20C', 'Food allergy poster does not contain text provided or approved by Department.'),
#  (datetime.datetime(2010, 7, 26, 0, 0), datetime.datetime(2099, 12, 31, 0, 0), 'N', '20D', '“Choking first aid” poster not posted. “Alcohol and pregnancy” warning sign not posted. Resuscitation equipment: exhaled air resuscitation masks (adult & pediatric), latex gloves, sign not posted. Inspection report sign not posted.'),
#  (datetime.datetime(2010, 7, 26, 0, 0), datetime.datetime(2099, 12, 31, 0, 0), 'N', '20E', 'Letter Grade or Grade Pending card not conspicuously posted and visible to passersby.'),
#  (datetime.datetime(2010, 7, 26, 0, 0), datetime.datetime(2099, 12, 31, 0, 0), 'N', '20F', 'Current letter grade card not posted.'),
#  (datetime.datetime(2010, 7, 26, 0, 0), datetime.datetime(2099, 12, 31, 0, 0), 'N', '22B', 'Toilet facility used by women does not have at least one covered garbage receptacle.'),
#  (datetime.datetime(2010, 7, 26, 0, 0), datetime.datetime(2099, 12, 31, 0, 0), 'N', '22C', 'Bulb not shielded or shatterproof, in areas where there is extreme heat, temperature changes, or where accidental contact may occur.'),
#  (datetime.datetime(2010, 7, 26, 0, 0), datetime.datetime(2099, 12, 31, 0, 0), 'N', '22E', 'ROP processing equipment not approved by DOHMH.'),
#  (datetime.datetime(2010, 7, 26, 0, 0), datetime.datetime(2099, 12, 31, 0, 0), 'N', '99B', 'Other general violation.')]

# %%
# %%sql
#
# select count(*) from filtered
# where violcode is not NULL;
# Out:
#  * postgresql://docker:***@nycinspection.tditrain.com:5433/NYCinspection
# 1 rows affected.
# [(517107,)]

# %%
# %%sql
#
# select count(*)
# from filtered
# where cuisinecode = '75' and violcode = '02G';
# Out:
#  * postgresql://docker:***@nycinspection.tditrain.com:5433/NYCinspection
# 1 rows affected.
# [(106,)]

# %%
# %%sql
#
# -- create a temp table #1 with the violations occured after Jan 1, 2014
#
# DROP TABLE IF EXISTS q5_temp;
# Create temporary table q5_temp as
#
# select filtered.cuisinecode, filtered.camis, filtered.violcode, valid_violations.violationdesc
# from filtered join valid_violations
# on filtered.violcode = valid_violations.violationcode;
# Out:
#  * postgresql://docker:***@nycinspection.tditrain.com:5433/NYCinspection
# Done.
# 517101 rows affected.
# []

# %%
# %%sql
#
# -- choose the violations that only occured after Jan 1st, 2014
#
# WITH valid_violations AS (
#     SELECT * FROM violations
#     WHERE enddate > '2014-01-01'
#     ),
#
# -- join 'valid_violations' and 'cuisine' tables to 'filtered' table
#
# temp AS (
#     SELECT cuisine.codedesc AS cuisine_name,
#            filtered.camis,
#            filtered.violcode,
#            valid_violations.violationdesc AS violation_description
#     FROM filtered
#         JOIN valid_violations
#             ON filtered.violcode = valid_violations.violationcode
#         JOIN cuisine
#             ON filtered.cuisinecode = cuisine.cuisinecode
#     ),
#
#
# temp2 AS (
#     SELECT cuisine_name,
#            COUNT(*) AS total_per_cuisine
#     FROM temp
#     GROUP BY cuisine_name
#     ),
#
#
# temp3 AS (
#     SELECT violcode, COUNT(*) AS total_violation_count
#     FROM temp
#     GROUP BY violcode
#     )
#
# select count(*) * 1.0 / (select count(*) from temp3) as ratio_per_type
# from temp3;
#
#
#
# SELECT t.cuisine_name, t.violcode, t.violation_description,
#        COUNT(*) AS viol_count,
#        COUNT(*) * 1.0 / temp2.total_per_cuisine AS ratio_per_cuisine
# FROM temp t
#     join temp2 ON t.cuisine_name = temp2.cuisine_name
# GROUP BY t.cuisine_name, t.violcode, t.violation_description, temp2.total_per_cuisine;
# Out:
#  * postgresql://docker:***@nycinspection.tditrain.com:5433/NYCinspection
# (psycopg2.errors.SyntaxError) syntax error at or near "SELECT"
# LINE 35: SELECT t.cuisine_name, t.violcode, t.violation_description,
#          ^
#
# [SQL: -- choose the violations that only occured after Jan 1st, 2014
#
# WITH valid_violations AS (
#     SELECT * FROM violations
#     WHERE enddate > '2014-01-01'
#     ),
#
# -- join 'valid_violations' and 'cuisine' tables to 'filtered' table
#
# temp AS (
#     SELECT cuisine.codedesc AS cuisine_name,
#            filtered.camis,
#            filtered.violcode,
#            valid_violations.violationdesc AS violation_description
#     FROM filtered
#         JOIN valid_violations
#             ON filtered.violcode = valid_violations.violationcode
#         JOIN cuisine
#             ON filtered.cuisinecode = cuisine.cuisinecode
#     ),
#
#
# temp2 as (
#     SELECT cuisine_name,
#            COUNT(*) AS total_per_cuisine
#     FROM temp
#     GROUP BY cuisine_name
#     ),
#
#
#
#
#
#
# SELECT t.cuisine_name, t.violcode, t.violation_description,
#        COUNT(*) AS viol_count,
#        COUNT(*) * 1.0 / temp2.total_per_cuisine AS ratio_per_cuisine
# FROM temp t
#     join temp2 ON t.cuisine_name = temp2.cuisine_name
# GROUP BY t.cuisine_name, t.violcode, t.violation_description, temp2.total_per_cuisine;]
# (Background on this error at: https://sqlalche.me/e/14/f405)

# %%
# %%sql
#
# -- create a temp table #2 by joining 'cuisine' table
#
# DROP TABLE IF EXISTS q5_temp2;
# Create temporary table q5_temp2 as
#
# select cuisine.codedesc as cuisine_name, q5_temp.camis, q5_temp.violcode, q5_temp.violationdesc
# from q5_temp join cuisine
# on q5_temp.cuisinecode = cuisine.cuisinecode;
# Out:
#  * postgresql://docker:***@nycinspection.tditrain.com:5433/NYCinspection
# Done.
# 517101 rows affected.
# []

# %%
# %%sql
#
# select * from q5_temp2
# limit 10;
# Out:
#  * postgresql://docker:***@nycinspection.tditrain.com:5433/NYCinspection
# 10 rows affected.
# [('Soups & Sandwiches', 41613314, '04L', "Evidence of mice or live mice present in facility's food and/or non-food areas."),
#  ('Ice Cream, Gelato, Yogurt, Ices', 41594064, '10F', 'Non-food contact surface improperly constructed. Unacceptable material used. Non-food contact surface or equipment improperly maintained and/or not properly sealed, raised, spaced or movable to allow accessibility for cleaning on all sides, above and underneath the unit.'),
#  ('Bakery', 41594110, '10D', 'Mechanical or natural ventilation system not provided, improperly installed, in disrepair and/or fails to prevent excessive build-up of grease, heat, steam condensation vapors, odors, smoke, and fumes.'),
#  ('Bakery', 41594110, '06E', 'Sanitized equipment or utensil, including in-use food dispensing utensil, improperly used or stored.'),
#  ('Bakery', 41594415, '10F', 'Non-food contact surface improperly constructed. Unacceptable material used. Non-food contact surface or equipment improperly maintained and/or not properly sealed, raised, spaced or movable to allow accessibility for cleaning on all sides, above and underneath the unit.'),
#  ('Bakery', 41594415, '10F', 'Non-food contact surface improperly constructed. Unacceptable material used. Non-food contact surface or equipment improperly maintained and/or not properly sealed, raised, spaced or movable to allow accessibility for cleaning on all sides, above and underneath the unit.'),
#  ('Mexican', 41594416, '10B', 'Plumbing not properly installed or maintained; anti-siphonage or backflow prevention device not provided where required; equipment or floor not properly drained; sewage disposal system in disrepair or not functioning properly.'),
#  ('Mexican', 41594416, '10F', 'Non-food contact surface improperly constructed. Unacceptable material used. Non-food contact surface or equipment improperly maintained and/or not properly sealed, raised, spaced or movable to allow accessibility for cleaning on all sides, above and underneath the unit.'),
#  ('Mexican', 41594416, '15L', 'Smoke free workplace smoking policy inadequate, not posted, not provided to employees.'),
#  ('Mexican', 41594416, '06C', 'Food not protected from potential source of contamination during storage, preparation, transportation, display or service.')]

# %%
# %%sql
#
# -- find the ratio number of violations of every type and the total number of violations in that cuisine
#
# with t2 as
#     (SELECT cuisine_name,
#             COUNT(*) AS total_per_cuisine
#      FROM q5_temp2
#      GROUP BY cuisine_name
#     )
#
# SELECT t.cuisine_name, t.violcode, t.violationdesc,
#        COUNT(*) AS viol_count,
#        COUNT(*) * 1.0 / t2.total_per_cuisine AS ratio_per_cuisine
# FROM q5_temp2 t
#      join t2 ON t.cuisine_name = t2.cuisine_name
# GROUP BY t.cuisine_name, t.violcode, t.violationdesc, t2.total_per_cuisine;
# Out:
#  * postgresql://docker:***@nycinspection.tditrain.com:5433/NYCinspection
# 4398 rows affected.
# [('Seafood', '04L', "Evidence of mice or live mice present in facility's food and/or non-food areas.", 210, Decimal('0.06505576208178438662')),
#  ('Polish', '10B', 'Plumbing not properly installed or maintained; anti-siphonage or backflow prevention device not provided where required; equipment or floor not properly drained; sewage disposal system in disrepair or not functioning properly.', 27, Decimal('0.03760445682451253482')),
#  ('Moroccan', '16B', 'The original nutritional fact labels and/or ingredient label for a cooking oil, shortening or margarine or food item sold in bulk, or acceptable manufacturer’s documentation not maintained on site.', 3, Decimal('0.01075268817204301075')),
#  ('Vietnamese/Cambodian/Malaysia', '10J', '""Wash hands” sign not posted at hand wash facility.', 2, Decimal('0.00109529025191675794')),
#  ('Tex-Mex', '05H', 'No facilities available to wash, rinse and sanitize utensils and/or equipment.', 1, Decimal('0.00035473572188719404')),
#  ('Other', '10C', 'Lighting inadequate; permanent lighting not provided in food preparation areas, ware washing areas, and storage rooms.', 3, Decimal('0.00160857908847184987')),
#  ('Vietnamese/Cambodian/Malaysia', '04F', 'Food, food preparation area, food storage area, area used by employees or patrons, contaminated by sewage or liquid waste.', 1, Decimal('0.00054764512595837897')),
#  ('Chinese/Japanese', '10E', 'Accurate thermometer not provided in refrigerated or hot holding equipment.', 5, Decimal('0.00384615384615384615')),
#  ('Asian', '15K', 'Operator failed to make good faith effort to inform smokers of the Smoke-free Act prohibition of smoking.', 11, Decimal('0.00144755888932754310')),
#  ('American ', '05B', 'Harmful, noxious gas or vapor detected. CO ~1 3 ppm.', 9, Decimal('0.000072335637357338048545')),
#  ('Egyptian', '08A', 'Facility not vermin proof. Harborage or conditions conducive to attracting vermin to the premises and/or allowing vermin to exist.', 36, Decimal('0.10810810810810810811')),
#  ('Bagels/Pretzels', '04M', "Live roaches present in facility's food and/or non-food areas.", 93, Decimal('0.02557755775577557756')),
#  ('Mexican', '06C', 'Food not protected from potential source of contamination during storage, preparation, transportation, display or service.', 909, Decimal('0.04971831756276322267')),
#  ('Chinese', '04M', "Live roaches present in facility's food and/or non-food areas.", 2986, Decimal('0.04927474050726909685')),
#  ('Bangladeshi', '99B', 'Other general violation.', 3, Decimal('0.00373599003735990037')),
#  ('Peruvian', '02H', 'Food not cooled by an approved method whereby the internal product temperature is reduced from 140º F to 70º F or less within 2 hours, and from 70º F to 41º F or less within 4 additional hours.', 19, Decimal('0.01011714589989350373')),
#  ('Pancakes/Waffles', '16A', 'A food containing artificial trans fat, with 0.5 grams or more of trans fat per serving, is being stored, distributed, held for service, used in preparation of a menu item, or served.', 1, Decimal('0.00246305418719211823')),
#  ('Australian', '02A', 'Food not cooked to required minimum temperature.', 1, Decimal('0.00403225806451612903')),
#  ('Ethiopian', '04N', 'Filth flies or food/refuse/sewage-associated (FRSA) flies present in facility’s food and/or non-food areas. Filth flies include house flies, little house flies, blow flies, bottle flies and flesh flies. Food/refuse/sewage-associated flies include fruit flies, drain flies and Phorid flies.', 13, Decimal('0.04377104377104377104')),
#  ('Salads', '02H', 'Food not cooled by an approved method whereby the internal product temperature is reduced from 140º F to 70º F or less within 2 hours, and from 70º F to 41º F or less within 4 additional hours.', 2, Decimal('0.00362318840579710145')),
#  ('Turkish', '10A', 'Toilet facility not maintained and provided with toilet paper, waste receptacle and self-closing door.', 15, Decimal('0.00991407799074686054')),
#  ('Chicken', '06C', 'Food not protected from potential source of contamination during storage, preparation, transportation, display or service.', 239, Decimal('0.03249932009790590155')),
#  ('French', '06I', 'Food not labeled in accordance with HACCP plan.', 2, Decimal('0.00027170221437304714')),
#  ('American ', '04L', "Evidence of mice or live mice present in facility's food and/or non-food areas.", 8351, Decimal('0.06711943417457000482')),
#  ('Czech', '05D', 'Hand washing facility not provided in or near food preparation area and toilet room. Hot and cold running water at adequate pressure to enable cleanliness of employees not provided at facility. Soap and an acceptable hand-drying device not provided.', 1, Decimal('0.00793650793650793651')),
#  ('Moroccan', '08A', 'Facility not vermin proof. Harborage or conditions conducive to attracting vermin to the premises and/or allowing vermin to exist.', 22, Decimal('0.07885304659498207885')),
#  ('Creole', '08B', 'Covered garbage receptacle not provided or inadequate, except that garbage receptacle may be uncovered during active use. Garbage storage area not properly constructed or maintained; grinder or compactor dirty.', 8, Decimal('0.01178203240058910162')),
#  ('Pizza', '15L', 'Smoke free workplace smoking policy inadequate, not posted, not provided to employees.', 58, Decimal('0.00227361818894551156')),
#  ('Pizza/Italian', '16C', 'Caloric content not posted on menus, menu boards or food tags, in a food service establishment that is 1 of 15 or more outlets operating the same typ ... (62 characters truncated) ...  as a franchise or doing business under the same name, for each menu item that is served in portions, the size and content of which are standardized.', 2, Decimal('0.00018919685933213509')),
#  ('Chinese', '05B', 'Harmful, noxious gas or vapor detected. CO ~1 3 ppm.', 7, Decimal('0.00011551345731777752')),
#  ('Thai', '20E', 'Letter Grade or Grade Pending card not conspicuously posted and visible to passersby.', 7, Decimal('0.00102699530516431925')),
#  ('Jewish/Kosher', '07A', 'Duties of an officer of the Department interfered with or obstructed.', 1, Decimal('0.00013320900492873318')),
#  ('Indian', '02B', 'Hot food item not held at or above 140º F.', 443, Decimal('0.05437584386890880079')),
#  ('Armenian', '04J', 'Appropriately scaled metal stem-type thermometer or thermocouple not provided or used to evaluate temperatures of potentially hazardous foods during cooking, cooling, reheating and holding.', 9, Decimal('0.01435406698564593301')),
#  ('Hamburgers', '04L', "Evidence of mice or live mice present in facility's food and/or non-food areas.", 380, Decimal('0.04979035639412997904')),
#  ('Ice Cream, Gelato, Yogurt, Ices', '20E', 'Letter Grade or Grade Pending card not conspicuously posted and visible to passersby.', 2, Decimal('0.00054779512462339085')),
#  ('Australian', '08A', 'Facility not vermin proof. Harborage or conditions conducive to attracting vermin to the premises and/or allowing vermin to exist.', 27, Decimal('0.10887096774193548387')),
#  ('Café/Coffee/Tea', '20E', 'Letter Grade or Grade Pending card not conspicuously posted and visible to passersby.', 8, Decimal('0.00054373683137361517')),
#  ('Seafood', '20E', 'Letter Grade or Grade Pending card not conspicuously posted and visible to passersby.', 1, Decimal('0.00030978934324659232')),
#  ('Armenian', '06D', 'Food contact surface not properly washed, rinsed and sanitized after each use and following any activity when contamination may have occurred.', 49, Decimal('0.07814992025518341308')),
#  ('Russian', '04J', 'Appropriately scaled metal stem-type thermometer or thermocouple not provided or used to evaluate temperatures of potentially hazardous foods during cooking, cooling, reheating and holding.', 22, Decimal('0.01098901098901098901')),
#  ('Sandwiches', '02I', 'Food prepared from ingredients at ambient temperature not cooled to 41º F or below within 4 hours.', 1, Decimal('0.00015413070283600493')),
#  ('Spanish', '06D', 'Food contact surface not properly washed, rinsed and sanitized after each use and following any activity when contamination may have occurred.', 668, Decimal('0.05130962439511483217')),
#  ('Bottled beverages, including water, sodas, juices, etc.', '15S', 'Flavored tobacco products sold or offered for sale.', 4, Decimal('0.00395256916996047431')),
#  ('Bakery', '09B', 'Thawing procedures improper.', 41, Decimal('0.00256378189094547274')),
#  ('Turkish', '15L', 'Smoke free workplace smoking policy inadequate, not posted, not provided to employees.', 9, Decimal('0.00594844679444811633')),
#  ('Mediterranean', '04A', 'Food Protection Certificate not held by supervisor of food operations.', 74, Decimal('0.01797425309691522954')),
#  ('Soups', '16B', 'The original nutritional fact labels and/or ingredient label for a cooking oil, shortening or margarine or food item sold in bulk, or acceptable manufacturer’s documentation not maintained on site.', 1, Decimal('0.02173913043478260870')),
#  ('Chinese/Cuban', '08B', 'Covered garbage receptacle not provided or inadequate, except that garbage receptacle may be uncovered during active use. Garbage storage area not properly constructed or maintained; grinder or compactor dirty.', 2, Decimal('0.00459770114942528736')),
#  ('Spanish', '10B', 'Plumbing not properly installed or maintained; anti-siphonage or backflow prevention device not provided where required; equipment or floor not properly drained; sewage disposal system in disrepair or not functioning properly.', 778, Decimal('0.05975881404101697519')),
#  ('Thai', '09A', 'Canned food product observed dented and not segregated from other consumable food items.', 63, Decimal('0.00924295774647887324')),
#  ('Greek', '02D', 'Precooked potentially hazardous food from commercial food processing establishment that is supposed to be heated, but is not heated to 140º F within 2 hours.', 1, Decimal('0.00039777247414478918')),
#  ('Donuts', '06A', 'Personal cleanliness inadequate. Outer garment soiled with possible contaminant.  Effective hair restraint not worn in an area where food is prepared.', 113, Decimal('0.01801658163265306122')),
#  ('Turkish', '10F', 'Non-food contact surface improperly constructed. Unacceptable material used. Non-food contact surface or equipment improperly maintained and/or not properly sealed, raised, spaced or movable to allow accessibility for cleaning on all sides, above and underneath the unit.', 160, Decimal('0.10575016523463317911')),
#  ('Hamburgers', '16A', 'A food containing artificial trans fat, with 0.5 grams or more of trans fat per serving, is being stored, distributed, held for service, used in preparation of a menu item, or served.', 5, Decimal('0.00065513626834381551')),
#  ('Bakery', '06B', 'Tobacco use, eating, or drinking from open container in food preparation, food storage or dishwashing area observed.', 117, Decimal('0.00731615807903951976')),
#  ('Egyptian', '02B', 'Hot food item not held at or above 140º F.', 7, Decimal('0.02102102102102102102')),
#  ('Italian', '03B', 'Shellfish not from approved source, improperly tagged/labeled; tags not retained for 90 days.', 37, Decimal('0.00145388816849385045')),
#  ('Eastern European', '10F', 'Non-food contact surface improperly constructed. Unacceptable material used. Non-food contact surface or equipment improperly maintained and/or not properly sealed, raised, spaced or movable to allow accessibility for cleaning on all sides, above and underneath the unit.', 144, Decimal('0.09782608695652173913')),
#  ('Pancakes/Waffles', '04A', 'Food Protection Certificate not held by supervisor of food operations.', 3, Decimal('0.00738916256157635468')),
#  ('Bagels/Pretzels', '10J', '""Wash hands” sign not posted at hand wash facility.', 11, Decimal('0.00302530253025302530')),
#  ('Middle Eastern', '20F', 'Current letter grade card not posted.', 22, Decimal('0.00688575899843505477')),
#  ('Thai', '02C', 'Hot food item that has been cooked and refrigerated is being held for service without first being reheated to 1 65º F or above within 2 hours.', 5, Decimal('0.00073356807511737089')),
#  ('Tex-Mex', '06G', 'HACCP plan not approved or approved HACCP plan not maintained on premises.', 1, Decimal('0.00035473572188719404')),
#  ('Seafood', '22B', 'Toilet facility used by women does not have at least one covered garbage receptacle.', 5, Decimal('0.00154894671623296159')),
#  ('Armenian', '04O', "Live animals other than fish in tank or service animal present in facility's food and/or non-food areas.", 1, Decimal('0.00159489633173843700')),
#  ('Chicken', '15I', '""No Smoking” and/or \'Smoking Permitted” sign not conspicuously posted. Health warning not present on \'Smoking Permitted”', 2, Decimal('0.00027196083763937993')),
#  ('African', '02G', 'Cold food item held above 41º F (smoked fish and reduced oxygen packaged foods above 38 ºF) except during necessary preparation.', 113, Decimal('0.06147986942328618063')),
#  ('Café/Coffee/Tea', '10G', 'Food service operation occurring in room used as living or sleeping quarters.', 3, Decimal('0.00020390131176510569')),
#  ('Peruvian', '20F', 'Current letter grade card not posted.', 11, Decimal('0.00585729499467518637')),
#  ('Mediterranean', '20D', '“Choking first aid” poster not posted. “Alcohol and pregnancy” warning sign not posted. Resuscitation equipment: exhaled air resuscitation masks (adult & pediatric), latex gloves, sign not posted. Inspection report sign not posted.', 18, Decimal('0.00437211561816856935')),
#  ('Korean', '20A', 'Food allergy information poster not conspicuously posted where food is being prepared or processed by food workers.', 4, Decimal('0.00057987822557262975')),
#  ('Pakistani', '22B', 'Toilet facility used by women does not have at least one covered garbage receptacle.', 1, Decimal('0.00123609394313967862')),
#  ('Bagels/Pretzels', '18C', 'Notice of the Department of Board of Health mutilated, obstructed, or removed.', 1, Decimal('0.00027502750275027503')),
#  ('Bakery', '09A', 'Canned food product observed dented and not segregated from other consumable food items.', 75, Decimal('0.00468984492246123062')),
#  ('Portuguese', '15L', 'Smoke free workplace smoking policy inadequate, not posted, not provided to employees.', 2, Decimal('0.00754716981132075472')),
#  ('Tapas', '10E', 'Accurate thermometer not provided in refrigerated or hot holding equipment.', 3, Decimal('0.00497512437810945274')),
#  ('Sandwiches/Salads/Mixed Buffet', '08A', 'Facility not vermin proof. Harborage or conditions conducive to attracting vermin to the premises and/or allowing vermin to exist.', 231, Decimal('0.07611202635914332784')),
#  ('Latin (Cuban, Dominican, Puerto Rican, South & Central American)', '03C', 'Eggs found dirty/cracked; liquid, frozen or powdered eggs not pasteurized.', 17, Decimal('0.00065758935478879777')),
#  ('Spanish', '04M', "Live roaches present in facility's food and/or non-food areas.", 398, Decimal('0.03057070435517320839')),
#  ('Juice, Smoothies, Fruit Salads', '04K', "Evidence of rats or live rats present in facility's food and/or non-food areas.", 10, Decimal('0.00380228136882129278')),
#  ('Pakistani', '10I', 'Single service item reused, improperly stored, dispensed; not used when required.', 6, Decimal('0.00741656365883807169')),
#  ('Café/Coffee/Tea', '15T', 'Original label for tobacco products sold or offered for sale.', 1, Decimal('0.000067967103921701896282')),
#  ('Other', '04C', 'Food worker does not use proper utensil to eliminate bare hand contact with food that will not receive adequate additional heat treatment.', 10, Decimal('0.00536193029490616622')),
#  ('Tex-Mex', '09C', 'Food contact surface not properly maintained.', 49, Decimal('0.01738205037247250798')),
#  ('Afghan', '09A', 'Canned food product observed dented and not segregated from other consumable food items.', 1, Decimal('0.00340136054421768707')),
#  ('Bakery', '04B', 'Food worker prepares food or handles utensil when ill with a disease transmissible by food, or have exposed infected cut or burn on hand.', 1, Decimal('0.000062531265632816408204')),
#  ('American ', '06I', 'Food not labeled in accordance with HACCP plan.', 14, Decimal('0.00011252210255585919')),
#  ('American ', '15I', '""No Smoking” and/or \'Smoking Permitted” sign not conspicuously posted. Health warning not present on \'Smoking Permitted”', 151, Decimal('0.00121363124899533837')),
#  ('Korean', '10B', 'Plumbing not properly installed or maintained; anti-siphonage or backflow prevention device not provided where required; equipment or floor not properly drained; sewage disposal system in disrepair or not functioning properly.', 473, Decimal('0.06857060017396346767')),
#  ('Chinese', '09B', 'Thawing procedures improper.', 1121, Decimal('0.01849865509331837159')),
#  ('Scandinavian', '22C', 'Bulb not shielded or shatterproof, in areas where there is extreme heat, temperature changes, or where accidental contact may occur.', 1, Decimal('0.00671140939597315436')),
#  ('Indian', '02H', 'Food not cooled by an approved method whereby the internal product temperature is reduced from 140º F to 70º F or less within 2 hours, and from 70º F to 41º F or less within 4 additional hours.', 112, Decimal('0.01374739167791825212')),
#  ('Soups & Sandwiches', '04M', "Live roaches present in facility's food and/or non-food areas.", 3, Decimal('0.00525394045534150613')),
#  ('Filipino', '04L', "Evidence of mice or live mice present in facility's food and/or non-food areas.", 29, Decimal('0.05132743362831858407')),
#  ('Chinese', '20F', 'Current letter grade card not posted.', 134, Decimal('0.00221125761151174112')),
#  ('Caribbean', '20F', 'Current letter grade card not posted.', 115, Decimal('0.00716555548632313540')),
#  ('Seafood', '10F', 'Non-food contact surface improperly constructed. Unacceptable material used. Non-food contact surface or equipment improperly maintained and/or not properly sealed, raised, spaced or movable to allow accessibility for cleaning on all sides, above and underneath the unit.', 402, Decimal('0.12453531598513011152')),
#  ('Bottled beverages, including water, sodas, juices, etc.', '15K', 'Operator failed to make good faith effort to inform smokers of the Smoke-free Act prohibition of smoking.', 1, Decimal('0.00098814229249011858')),
#  ('Salads', '04C', 'Food worker does not use proper utensil to eliminate bare hand contact with food that will not receive adequate additional heat treatment.', 1, Decimal('0.00181159420289855072')),
#  ('Southwestern', '16A', 'A food containing artificial trans fat, with 0.5 grams or more of trans fat per serving, is being stored, distributed, held for service, used in preparation of a menu item, or served.', 1, Decimal('0.00495049504950495050')),
#  ('Pizza/Italian', '08A', 'Facility not vermin proof. Harborage or conditions conducive to attracting vermin to the premises and/or allowing vermin to exist.', 1003, Decimal('0.09488222495506574591')),
#  ('Iranian', '04N', 'Filth flies or food/refuse/sewage-associated (FRSA) flies present in facility’s food and/or non-food areas. Filth flies include house flies, little house flies, blow flies, bottle flies and flesh flies. Food/refuse/sewage-associated flies include fruit flies, drain flies and Phorid flies.', 3, Decimal('0.03797468354430379747')),
#  ('Thai', '09C', 'Food contact surface not properly maintained.', 74, Decimal('0.01085680751173708920')),
#  ('Continental', '06A', 'Personal cleanliness inadequate. Outer garment soiled with possible contaminant.  Effective hair restraint not worn in an area where food is prepared.', 15, Decimal('0.01532175689479060266')),
#  ('Chinese/Japanese', '02G', 'Cold food item held above 41º F (smoked fish and reduced oxygen packaged foods above 38 ºF) except during necessary preparation.', 117, Decimal('0.09000000000000000000')),
#  ('Greek', '15L', 'Smoke free workplace smoking policy inadequate, not posted, not provided to employees.', 13, Decimal('0.00517104216388225935')),
#  ('Sandwiches/Salads/Mixed Buffet', '06G', 'HACCP plan not approved or approved HACCP plan not maintained on premises.', 1, Decimal('0.00032948929159802306')),
#  ('Bagels/Pretzels', '04N', 'Filth flies or food/refuse/sewage-associated (FRSA) flies present in facility’s food and/or non-food areas. Filth flies include house flies, little house flies, blow flies, bottle flies and flesh flies. Food/refuse/sewage-associated flies include fruit flies, drain flies and Phorid flies.', 158, Decimal('0.04345434543454345435')),
#  ('Hamburgers', '10B', 'Plumbing not properly installed or maintained; anti-siphonage or backflow prevention device not provided where required; equipment or floor not properly drained; sewage disposal system in disrepair or not functioning properly.', 522, Decimal('0.06839622641509433962')),
#  ('Spanish', '04O', "Live animals other than fish in tank or service animal present in facility's food and/or non-food areas.", 19, Decimal('0.00145940548429218834')),
#  ('Juice, Smoothies, Fruit Salads', '04D', 'Food worker does not wash hands thoroughly after using the toilet, coughing, sneezing, smoking, eating, preparing raw foods or otherwise contaminating hands.', 4, Decimal('0.00152091254752851711')),
#  ('Eastern European', '05F', 'Insufficient or no refrigerated or hot holding equipment to keep potentially hazardous foods at required temperatures.', 3, Decimal('0.00203804347826086957')),
#  ('Turkish', '10H', 'Proper sanitization not provided for utensil ware washing operation.', 31, Decimal('0.02048909451421017845')),
#  ('Spanish', '04N', 'Filth flies or food/refuse/sewage-associated (FRSA) flies present in facility’s food and/or non-food areas. Filth flies include house flies, little house flies, blow flies, bottle flies and flesh flies. Food/refuse/sewage-associated flies include fruit flies, drain flies and Phorid flies.', 584, Decimal('0.04485751593824410477')),
#  ('American ', '20A', 'Food allergy information poster not conspicuously posted where food is being prepared or processed by food workers.', 241, Decimal('0.00193698762256871886')),
#  ('Sandwiches/Salads/Mixed Buffet', '10J', '""Wash hands” sign not posted at hand wash facility.', 19, Decimal('0.00626029654036243822')),
#  ('Seafood', '22A', 'Nuisance created or allowed to exist. Facility not free from unsafe, hazardous, offensive or annoying conditions.', 11, Decimal('0.00340768277571251549')),
#  ('French', '04K', "Evidence of rats or live rats present in facility's food and/or non-food areas.", 43, Decimal('0.00584159760902051352')),
#  ('Korean', '02A', 'Food not cooked to required minimum temperature.', 5, Decimal('0.00072484778196578718')),
#  ('Pancakes/Waffles', '02B', 'Hot food item not held at or above 140º F.', 14, Decimal('0.03448275862068965517')),
#  ('Delicatessen', '08B', 'Covered garbage receptacle not provided or inadequate, except that garbage receptacle may be uncovered during active use. Garbage storage area not properly constructed or maintained; grinder or compactor dirty.', 41, Decimal('0.00430310663308144416')),
#  ('Chinese/Japanese', '04D', 'Food worker does not wash hands thoroughly after using the toilet, coughing, sneezing, smoking, eating, preparing raw foods or otherwise contaminating hands.', 3, Decimal('0.00230769230769230769')),
#  ('Polish', '10J', '""Wash hands” sign not posted at hand wash facility.', 2, Decimal('0.00278551532033426184')),
#  ('Creole', '99B', 'Other general violation.', 4, Decimal('0.00589101620029455081')),
#  ('Chinese/Cuban', '06F', 'Wiping cloths soiled or not stored in sanitizing solution.', 11, Decimal('0.02528735632183908046')),
#  ('Donuts', '04O', "Live animals other than fish in tank or service animal present in facility's food and/or non-food areas.", 4, Decimal('0.00063775510204081633')),
#  ('Hotdogs', '10E', 'Accurate thermometer not provided in refrigerated or hot holding equipment.', 8, Decimal('0.01851851851851851852')),
#  ('Australian', '04N', 'Filth flies or food/refuse/sewage-associated (FRSA) flies present in facility’s food and/or non-food areas. Filth flies include house flies, little house flies, blow flies, bottle flies and flesh flies. Food/refuse/sewage-associated flies include fruit flies, drain flies and Phorid flies.', 15, Decimal('0.06048387096774193548')),
#  ('Donuts', '06C', 'Food not protected from potential source of contamination during storage, preparation, transportation, display or service.', 323, Decimal('0.05149872448979591837')),
#  ('Continental', '06B', 'Tobacco use, eating, or drinking from open container in food preparation, food storage or dishwashing area observed.', 4, Decimal('0.00408580183861082737')),
#  ('Delicatessen', '02I', 'Food prepared from ingredients at ambient temperature not cooled to 41º F or below within 4 hours.', 2, Decimal('0.00020990764063811923')),
#  ('Armenian', '08A', 'Facility not vermin proof. Harborage or conditions conducive to attracting vermin to the premises and/or allowing vermin to exist.', 52, Decimal('0.08293460925039872408')),
#  ('Thai', '06F', 'Wiping cloths soiled or not stored in sanitizing solution.', 185, Decimal('0.02714201877934272300')),
#  ('Chicken', '06A', 'Personal cleanliness inadequate. Outer garment soiled with possible contaminant.  Effective hair restraint not worn in an area where food is prepared.', 124, Decimal('0.01686157193364155562')),
#  ('Peruvian', '04N', 'Filth flies or food/refuse/sewage-associated (FRSA) flies present in facility’s food and/or non-food areas. Filth flies include house flies, little house flies, blow flies, bottle flies and flesh flies. Food/refuse/sewage-associated flies include fruit flies, drain flies and Phorid flies.', 82, Decimal('0.04366347177848775293')),
#  ('Australian', '10H', 'Proper sanitization not provided for utensil ware washing operation.', 7, Decimal('0.02822580645161290323')),
#  ('Chinese/Japanese', '09A', 'Canned food product observed dented and not segregated from other consumable food items.', 9, Decimal('0.00692307692307692308')),
#  ('Chicken', '10F', 'Non-food contact surface improperly constructed. Unacceptable material used. Non-food contact surface or equipment improperly maintained and/or not properly sealed, raised, spaced or movable to allow accessibility for cleaning on all sides, above and underneath the unit.', 1134, Decimal('0.15420179494152841991')),
#  ('Brazilian', '06D', 'Food contact surface not properly washed, rinsed and sanitized after each use and following any activity when contamination may have occurred.', 35, Decimal('0.05247376311844077961')),
#  ('Juice, Smoothies, Fruit Salads', '10E', 'Accurate thermometer not provided in refrigerated or hot holding equipment.', 20, Decimal('0.00760456273764258555')),
#  ('Latin (Cuban, Dominican, Puerto Rican, South & Central American)', '06C', 'Food not protected from potential source of contamination during storage, preparation, transportation, display or service.', 1133, Decimal('0.04382639641033575739')),
#  ('Juice, Smoothies, Fruit Salads', '05A', 'Sewage disposal system improper or unapproved.', 1, Decimal('0.00038022813688212928')),
#  ('Not Listed/Not Applicable', '05D', 'Hand washing facility not provided in or near food preparation area and toilet room. Hot and cold running water at adequate pressure to enable cleanliness of employees not provided at facility. Soap and an acceptable hand-drying device not provided.', 6, Decimal('0.04724409448818897638')),
#  ('Italian', '20D', '“Choking first aid” poster not posted. “Alcohol and pregnancy” warning sign not posted. Resuscitation equipment: exhaled air resuscitation masks (adult & pediatric), latex gloves, sign not posted. Inspection report sign not posted.', 58, Decimal('0.00227906793980117097')),
#  ('Egyptian', '10E', 'Accurate thermometer not provided in refrigerated or hot holding equipment.', 2, Decimal('0.00600600600600600601')),
#  ('Juice, Smoothies, Fruit Salads', '03A', 'Food from unapproved or unknown source or home canned. Reduced oxygen packaged (ROP) fish not frozen before processing; or ROP foods prepared on premises transported to another site.', 14, Decimal('0.00532319391634980989')),
#  ('Mexican', '22B', 'Toilet facility used by women does not have at least one covered garbage receptacle.', 10, Decimal('0.00054695618880927638')),
#  ('Caribbean', '04M', "Live roaches present in facility's food and/or non-food areas.", 498, Decimal('0.03102997071468627329')),
#  ('Egyptian', '06E', 'Sanitized equipment or utensil, including in-use food dispensing utensil, improperly used or stored.', 6, Decimal('0.01801801801801801802')),
#  ('Peruvian', '09B', 'Thawing procedures improper.', 19, Decimal('0.01011714589989350373')),
#  ('Continental', '10H', 'Proper sanitization not provided for utensil ware washing operation.', 19, Decimal('0.01940755873340143003')),
#  ('Latin (Cuban, Dominican, Puerto Rican, South & Central American)', '06E', 'Sanitized equipment or utensil, including in-use food dispensing utensil, improperly used or stored.', 631, Decimal('0.02440816958069008201')),
#  ('Thai', '20A', 'Food allergy information poster not conspicuously posted where food is being prepared or processed by food workers.', 2, Decimal('0.00029342723004694836')),
#  ('Indian', '09C', 'Food contact surface not properly maintained.', 101, Decimal('0.01239720142383699521')),
#  ('French', '06C', 'Food not protected from potential source of contamination during storage, preparation, transportation, display or service.', 375, Decimal('0.05094416519494633881')),
#  ('Latin (Cuban, Dominican, Puerto Rican, South & Central American)', '18A', 'Current valid permit, registration or other authorization to operate establishment not available.', 3, Decimal('0.00011604518025684667')),
#  ('German', '08B', 'Covered garbage receptacle not provided or inadequate, except that garbage receptacle may be uncovered during active use. Garbage storage area not properly constructed or maintained; grinder or compactor dirty.', 2, Decimal('0.00236966824644549763')),
#  ('Southwestern', '04D', 'Food worker does not wash hands thoroughly after using the toilet, coughing, sneezing, smoking, eating, preparing raw foods or otherwise contaminating hands.', 1, Decimal('0.00495049504950495050')),
#  ('Other', '08A', 'Facility not vermin proof. Harborage or conditions conducive to attracting vermin to the premises and/or allowing vermin to exist.', 137, Decimal('0.07345844504021447721')),
#  ('Asian', '05E', 'Toilet facility not provided for employees or for patrons when required.', 2, Decimal('0.00026319252533228056')),
#  ('Italian', '08A', 'Facility not vermin proof. Harborage or conditions conducive to attracting vermin to the premises and/or allowing vermin to exist.', 2133, Decimal('0.08381468819992927031')),
#  ('Soups & Sandwiches', '04A', 'Food Protection Certificate not held by supervisor of food operations.', 7, Decimal('0.01225919439579684764')),
#  ('Bottled beverages, including water, sodas, juices, etc.', '09C', 'Food contact surface not properly maintained.', 5, Decimal('0.00494071146245059289')),
#  ('Japanese', '02C', 'Hot food item that has been cooked and refrigerated is being held for service without first being reheated to 1 65º F or above within 2 hours.', 11, Decimal('0.00060060060060060060')),
#  ('Caribbean', '16C', 'Caloric content not posted on menus, menu boards or food tags, in a food service establishment that is 1 of 15 or more outlets operating the same typ ... (62 characters truncated) ...  as a franchise or doing business under the same name, for each menu item that is served in portions, the size and content of which are standardized.', 3, Decimal('0.00018692753442582092')),
#  ('Mediterranean', '15K', 'Operator failed to make good faith effort to inform smokers of the Smoke-free Act prohibition of smoking.', 2, Decimal('0.00048579062424095215')),
#  ('Indian', '20A', 'Food allergy information poster not conspicuously posted where food is being prepared or processed by food workers.', 13, Decimal('0.00159567939118693998')),
#  ('Scandinavian', '06D', 'Food contact surface not properly washed, rinsed and sanitized after each use and following any activity when contamination may have occurred.', 13, Decimal('0.08724832214765100671')),
#  ('Japanese', '04N', 'Filth flies or food/refuse/sewage-associated (FRSA) flies present in facility’s food and/or non-food areas. Filth flies include house flies, little house flies, blow flies, bottle flies and flesh flies. Food/refuse/sewage-associated flies include fruit flies, drain flies and Phorid flies.', 428, Decimal('0.02336882336882336882')),
#  ('Seafood', '06C', 'Food not protected from potential source of contamination during storage, preparation, transportation, display or service.', 141, Decimal('0.04368029739776951673')),
#  ('Korean', '10I', 'Single service item reused, improperly stored, dispensed; not used when required.', 47, Decimal('0.00681356915047839954')),
#  ('Seafood', '16A', 'A food containing artificial trans fat, with 0.5 grams or more of trans fat per serving, is being stored, distributed, held for service, used in preparation of a menu item, or served.', 3, Decimal('0.00092936802973977695')),
#  ('Pizza/Italian', '16F', 'Specific caloric content or range thereof not posted on menus, menu boards or food tags for each menu item offered as a combination meal with multiple options that are listed as single items.', 1, Decimal('0.000094598429666067543279')),
#  ('Japanese', '22A', 'Nuisance created or allowed to exist. Facility not free from unsafe, hazardous, offensive or annoying conditions.', 57, Decimal('0.00311220311220311220')),
#  ('Indian', '05D', 'Hand washing facility not provided in or near food preparation area and toilet room. Hot and cold running water at adequate pressure to enable cleanliness of employees not provided at facility. Soap and an acceptable hand-drying device not provided.', 73, Decimal('0.00896035350435743218')),
#  ('Chinese/Cuban', '04K', "Evidence of rats or live rats present in facility's food and/or non-food areas.", 2, Decimal('0.00459770114942528736')),
#  ('Brazilian', '04J', 'Appropriately scaled metal stem-type thermometer or thermocouple not provided or used to evaluate temperatures of potentially hazardous foods during cooking, cooling, reheating and holding.', 6, Decimal('0.00899550224887556222')),
#  ('Ethiopian', '04L', "Evidence of mice or live mice present in facility's food and/or non-food areas.", 27, Decimal('0.09090909090909090909')),
#  ('Café/Coffee/Tea', '06B', 'Tobacco use, eating, or drinking from open container in food preparation, food storage or dishwashing area observed.', 84, Decimal('0.00570923672942295929')),
#  ('Scandinavian', '04L', "Evidence of mice or live mice present in facility's food and/or non-food areas.", 11, Decimal('0.07382550335570469799')),
#  ('Donuts', '10F', 'Non-food contact surface improperly constructed. Unacceptable material used. Non-food contact surface or equipment improperly maintained and/or not properly sealed, raised, spaced or movable to allow accessibility for cleaning on all sides, above and underneath the unit.', 1336, Decimal('0.21301020408163265306')),
#  ('African', '15L', 'Smoke free workplace smoking policy inadequate, not posted, not provided to employees.', 4, Decimal('0.00217627856365614799')),
#  ('Creole', '04C', 'Food worker does not use proper utensil to eliminate bare hand contact with food that will not receive adequate additional heat treatment.', 1, Decimal('0.00147275405007363770')),
#  ('Chinese', '05I', 'Refrigeration used to implement HACCP plan not equipped with an electronic system that continuously monitors time and temperature.', 1, Decimal('0.000016501922473968217297')),
#  ('Irish', '20F', 'Current letter grade card not posted.', 26, Decimal('0.00594014164953164268')),
#  ('Portuguese', '10B', 'Plumbing not properly installed or maintained; anti-siphonage or backflow prevention device not provided where required; equipment or floor not properly drained; sewage disposal system in disrepair or not functioning properly.', 16, Decimal('0.06037735849056603774')),
#  ('Korean', '06A', 'Personal cleanliness inadequate. Outer garment soiled with possible contaminant.  Effective hair restraint not worn in an area where food is prepared.', 178, Decimal('0.02580458103798202378')),
#  ('Pancakes/Waffles', '06F', 'Wiping cloths soiled or not stored in sanitizing solution.', 10, Decimal('0.02463054187192118227')),
#  ('German', '03C', 'Eggs found dirty/cracked; liquid, frozen or powdered eggs not pasteurized.', 2, Decimal('0.00236966824644549763')),
#  ('Southwestern', '02B', 'Hot food item not held at or above 140º F.', 12, Decimal('0.05940594059405940594')),
#  ('Greek', '05D', 'Hand washing facility not provided in or near food preparation area and toilet room. Hot and cold running water at adequate pressure to enable cleanliness of employees not provided at facility. Soap and an acceptable hand-drying device not provided.', 26, Decimal('0.01034208432776451870')),
#  ('Café/Coffee/Tea', '20F', 'Current letter grade card not posted.', 64, Decimal('0.00434989465098892136')),
#  ('Pakistani', '06B', 'Tobacco use, eating, or drinking from open container in food preparation, food storage or dishwashing area observed.', 10, Decimal('0.01236093943139678616')),
#  ('Delicatessen', '10F', 'Non-food contact surface improperly constructed. Unacceptable material used. Non-food contact surface or equipment improperly maintained and/or not properly sealed, raised, spaced or movable to allow accessibility for cleaning on all sides, above and underneath the unit.', 1203, Decimal('0.12625944584382871537')),
#  ('Bagels/Pretzels', '04D', 'Food worker does not wash hands thoroughly after using the toilet, coughing, sneezing, smoking, eating, preparing raw foods or otherwise contaminating hands.', 6, Decimal('0.00165016501650165017')),
#  ('Eastern European', '09A', 'Canned food product observed dented and not segregated from other consumable food items.', 8, Decimal('0.00543478260869565217')),
#  ('Barbecue', '05H', 'No facilities available to wash, rinse and sanitize utensils and/or equipment.', 1, Decimal('0.00126262626262626263')),
#  ('Mediterranean', '06C', 'Food not protected from potential source of contamination during storage, preparation, transportation, display or service.', 234, Decimal('0.05683750303619140151')),
#  ('Pizza/Italian', '02H', 'Food not cooled by an approved method whereby the internal product temperature is reduced from 140º F to 70º F or less within 2 hours, and from 70º F to 41º F or less within 4 additional hours.', 73, Decimal('0.00690568536562293066')),
#  ('Soups & Sandwiches', '10H', 'Proper sanitization not provided for utensil ware washing operation.', 4, Decimal('0.00700525394045534151')),
#  ('Scandinavian', '02G', 'Cold food item held above 41º F (smoked fish and reduced oxygen packaged foods above 38 ºF) except during necessary preparation.', 16, Decimal('0.10738255033557046980')),
#  ('Chinese', '15K', 'Operator failed to make good faith effort to inform smokers of the Smoke-free Act prohibition of smoking.', 16, Decimal('0.00026403075958349148')),
#  ('Mexican', '03D', 'Canned food product observed swollen, leaking or rusted, and not segregated from other consumable food items .', 1, Decimal('0.000054695618880927637696')),
#  ('Bangladeshi', '10E', 'Accurate thermometer not provided in refrigerated or hot holding equipment.', 3, Decimal('0.00373599003735990037')),
#  ('Chinese', '04K', "Evidence of rats or live rats present in facility's food and/or non-food areas.", 522, Decimal('0.00861400353141140943')),
#  ('Soul Food', '04M', "Live roaches present in facility's food and/or non-food areas.", 44, Decimal('0.04313725490196078431')),
#  ('Bakery', '16B', 'The original nutritional fact labels and/or ingredient label for a cooking oil, shortening or margarine or food item sold in bulk, or acceptable manufacturer’s documentation not maintained on site.', 82, Decimal('0.00512756378189094547')),
#  ('Salads', '08C', 'Pesticide use not in accordance with label or applicable laws. Prohibited chemical used/stored. Open bait station used.', 5, Decimal('0.00905797101449275362')),
#  ('Bangladeshi', '20A', 'Food allergy information poster not conspicuously posted where food is being prepared or processed by food workers.', 2, Decimal('0.00249066002490660025')),
#  ('Eastern European', '04D', 'Food worker does not wash hands thoroughly after using the toilet, coughing, sneezing, smoking, eating, preparing raw foods or otherwise contaminating hands.', 2, Decimal('0.00135869565217391304')),
#  ('Pizza/Italian', '04C', 'Food worker does not use proper utensil to eliminate bare hand contact with food that will not receive adequate additional heat treatment.', 118, Decimal('0.01116261470059597011')),
#  ('Sandwiches/Salads/Mixed Buffet', '06E', 'Sanitized equipment or utensil, including in-use food dispensing utensil, improperly used or stored.', 65, Decimal('0.02141680395387149918')),
#  ('Nuts/Confectionary', '08A', 'Facility not vermin proof. Harborage or conditions conducive to attracting vermin to the premises and/or allowing vermin to exist.', 4, Decimal('0.06779661016949152542')),
#  ('Portuguese', '10H', 'Proper sanitization not provided for utensil ware washing operation.', 6, Decimal('0.02264150943396226415')),
#  ('Brazilian', '08A', 'Facility not vermin proof. Harborage or conditions conducive to attracting vermin to the premises and/or allowing vermin to exist.', 60, Decimal('0.08995502248875562219')),
#  ('Soul Food', '10E', 'Accurate thermometer not provided in refrigerated or hot holding equipment.', 9, Decimal('0.00882352941176470588')),
#  ('Bagels/Pretzels', '06A', 'Personal cleanliness inadequate. Outer garment soiled with possible contaminant.  Effective hair restraint not worn in an area where food is prepared.', 72, Decimal('0.01980198019801980198')),
#  ('Continental', '04M', "Live roaches present in facility's food and/or non-food areas.", 34, Decimal('0.03472931562819203269')),
#  ('Irish', '04M', "Live roaches present in facility's food and/or non-food areas.", 73, Decimal('0.01667809001599268906')),
#  ('Tex-Mex', '03C', 'Eggs found dirty/cracked; liquid, frozen or powdered eggs not pasteurized.', 1, Decimal('0.00035473572188719404')),
#  ('Peruvian', '06E', 'Sanitized equipment or utensil, including in-use food dispensing utensil, improperly used or stored.', 67, Decimal('0.03567625133120340788')),
#  ('Korean', '04O', "Live animals other than fish in tank or service animal present in facility's food and/or non-food areas.", 5, Decimal('0.00072484778196578718')),
#  ('Asian', '16A', 'A food containing artificial trans fat, with 0.5 grams or more of trans fat per serving, is being stored, distributed, held for service, used in preparation of a menu item, or served.', 7, Decimal('0.00092117383866298197')),
#  ('Thai', '10I', 'Single service item reused, improperly stored, dispensed; not used when required.', 42, Decimal('0.00616197183098591549')),
#  ('Fruits/Vegetables', '99B', 'Other general violation.', 1, Decimal('0.02000000000000000000')),
#  ('Salads', '06A', 'Personal cleanliness inadequate. Outer garment soiled with possible contaminant.  Effective hair restraint not worn in an area where food is prepared.', 5, Decimal('0.00905797101449275362')),
#  ('Hamburgers', '22A', 'Nuisance created or allowed to exist. Facility not free from unsafe, hazardous, offensive or annoying conditions.', 43, Decimal('0.00563417190775681342')),
#  ('Creole', '04K', "Evidence of rats or live rats present in facility's food and/or non-food areas.", 2, Decimal('0.00294550810014727541')),
#  ('Seafood', '03B', 'Shellfish not from approved source, improperly tagged/labeled; tags not retained for 90 days.', 6, Decimal('0.00185873605947955390')),
#  ('Latin (Cuban, Dominican, Puerto Rican, South & Central American)', '02C', 'Hot food item that has been cooked and refrigerated is being held for service without first being reheated to 1 65º F or above within 2 hours.', 26, Decimal('0.00100572489555933777')),
#  ('Creole', '04L', "Evidence of mice or live mice present in facility's food and/or non-food areas.", 71, Decimal('0.10456553755522827688')),
#  ('Tapas', '09C', 'Food contact surface not properly maintained.', 7, Decimal('0.01160862354892205638')),
#  ('Creole', '04H', 'Raw, cooked or prepared food is adulterated, contaminated, cross-contaminated, or not discarded in accordance with HACCP plan.', 16, Decimal('0.02356406480117820324')),
#  ('Czech', '04A', 'Food Protection Certificate not held by supervisor of food operations.', 1, Decimal('0.00793650793650793651')),
#  ('Tapas', '06F', 'Wiping cloths soiled or not stored in sanitizing solution.', 9, Decimal('0.01492537313432835821')),
#  ('Chinese/Japanese', '03C', 'Eggs found dirty/cracked; liquid, frozen or powdered eggs not pasteurized.', 1, Decimal('0.00076923076923076923')),
#  ('Soups & Sandwiches', '02G', 'Cold food item held above 41º F (smoked fish and reduced oxygen packaged foods above 38 ºF) except during necessary preparation.', 106, Decimal('0.18563922942206654991')),
#  ('Soul Food', '04J', 'Appropriately scaled metal stem-type thermometer or thermocouple not provided or used to evaluate temperatures of potentially hazardous foods during cooking, cooling, reheating and holding.', 13, Decimal('0.01274509803921568627')),
#  ('African', '04A', 'Food Protection Certificate not held by supervisor of food operations.', 86, Decimal('0.04678998911860718172')),
#  ('Delicatessen', '02H', 'Food not cooled by an approved method whereby the internal product temperature is reduced from 140º F to 70º F or less within 2 hours, and from 70º F to 41º F or less within 4 additional hours.', 55, Decimal('0.00577246011754827876')),
#  ('Afghan', '04K', "Evidence of rats or live rats present in facility's food and/or non-food areas.", 4, Decimal('0.01360544217687074830')),
#  ('Czech', '09A', 'Canned food product observed dented and not segregated from other consumable food items.', 1, Decimal('0.00793650793650793651')),
#  ('Cajun', '06E', 'Sanitized equipment or utensil, including in-use food dispensing utensil, improperly used or stored.', 6, Decimal('0.03370786516853932584')),
#  ('Australian', '03A', 'Food from unapproved or unknown source or home canned. Reduced oxygen packaged (ROP) fish not frozen before processing; or ROP foods prepared on premises transported to another site.', 1, Decimal('0.00403225806451612903')),
#  ('Indonesian', '04J', 'Appropriately scaled metal stem-type thermometer or thermocouple not provided or used to evaluate temperatures of potentially hazardous foods during cooking, cooling, reheating and holding.', 4, Decimal('0.01877934272300469484')),
#  ('Italian', '06E', 'Sanitized equipment or utensil, including in-use food dispensing utensil, improperly used or stored.', 887, Decimal('0.03485402176902825258')),
#  ('German', '04H', 'Raw, cooked or prepared food is adulterated, contaminated, cross-contaminated, or not discarded in accordance with HACCP plan.', 35, Decimal('0.04146919431279620853')),
#  ('Cajun', '16B', 'The original nutritional fact labels and/or ingredient label for a cooking oil, shortening or margarine or food item sold in bulk, or acceptable manufacturer’s documentation not maintained on site.', 3, Decimal('0.01685393258426966292')),
#  ('Filipino', '06C', 'Food not protected from potential source of contamination during storage, preparation, transportation, display or service.', 27, Decimal('0.04778761061946902655')),
#  ('French', '16A', 'A food containing artificial trans fat, with 0.5 grams or more of trans fat per serving, is being stored, distributed, held for service, used in preparation of a menu item, or served.', 6, Decimal('0.00081510664311914142')),
#  ('Indonesian', '04A', 'Food Protection Certificate not held by supervisor of food operations.', 5, Decimal('0.02347417840375586854')),
#  ('Filipino', '02B', 'Hot food item not held at or above 140º F.', 49, Decimal('0.08672566371681415929')),
#  ('Iranian', '10J', '""Wash hands” sign not posted at hand wash facility.', 1, Decimal('0.01265822784810126582')),
# ...
#  ('Hotdogs', '08A', 'Facility not vermin proof. Harborage or conditions conducive to attracting vermin to the premises and/or allowing vermin to exist.', 39, Decimal('0.09027777777777777778')),
#  ('Pizza/Italian', '04J', 'Appropriately scaled metal stem-type thermometer or thermocouple not provided or used to evaluate temperatures of potentially hazardous foods during cooking, cooling, reheating and holding.', 136, Decimal('0.01286538643458518589')),
#  ('Chinese/Cuban', '10F', 'Non-food contact surface improperly constructed. Unacceptable material used. Non-food contact surface or equipment improperly maintained and/or not properly sealed, raised, spaced or movable to allow accessibility for cleaning on all sides, above and underneath the unit.', 48, Decimal('0.11034482758620689655')),
#  ('Bangladeshi', '04N', 'Filth flies or food/refuse/sewage-associated (FRSA) flies present in facility’s food and/or non-food areas. Filth flies include house flies, little house flies, blow flies, bottle flies and flesh flies. Food/refuse/sewage-associated flies include fruit flies, drain flies and Phorid flies.', 32, Decimal('0.03985056039850560399')),
#  ('Cajun', '08A', 'Facility not vermin proof. Harborage or conditions conducive to attracting vermin to the premises and/or allowing vermin to exist.', 14, Decimal('0.07865168539325842697')),
#  ('Pakistani', '04L', "Evidence of mice or live mice present in facility's food and/or non-food areas.", 74, Decimal('0.09147095179233621755')),
#  ('Barbecue', '10E', 'Accurate thermometer not provided in refrigerated or hot holding equipment.', 12, Decimal('0.01515151515151515152')),
#  ('Steak', '06A', 'Personal cleanliness inadequate. Outer garment soiled with possible contaminant.  Effective hair restraint not worn in an area where food is prepared.', 27, Decimal('0.01517706576728499157')),
#  ('Bakery', '04D', 'Food worker does not wash hands thoroughly after using the toilet, coughing, sneezing, smoking, eating, preparing raw foods or otherwise contaminating hands.', 13, Decimal('0.00081290645322661331')),
#  ('Indonesian', '09C', 'Food contact surface not properly maintained.', 1, Decimal('0.00469483568075117371')),
#  ('Bagels/Pretzels', '03C', 'Eggs found dirty/cracked; liquid, frozen or powdered eggs not pasteurized.', 8, Decimal('0.00220022002200220022')),
#  ('Japanese', '09B', 'Thawing procedures improper.', 275, Decimal('0.01501501501501501502')),
#  ('Jewish/Kosher', '04A', 'Food Protection Certificate not held by supervisor of food operations.', 108, Decimal('0.01438657253230318370')),
#  ('Soups', '22A', 'Nuisance created or allowed to exist. Facility not free from unsafe, hazardous, offensive or annoying conditions.', 1, Decimal('0.02173913043478260870')),
#  ('Soups', '02G', 'Cold food item held above 41º F (smoked fish and reduced oxygen packaged foods above 38 ºF) except during necessary preparation.', 3, Decimal('0.06521739130434782609')),
#  ('Chinese/Cuban', '04H', 'Raw, cooked or prepared food is adulterated, contaminated, cross-contaminated, or not discarded in accordance with HACCP plan.', 4, Decimal('0.00919540229885057471')),
#  ('Portuguese', '16B', 'The original nutritional fact labels and/or ingredient label for a cooking oil, shortening or margarine or food item sold in bulk, or acceptable manufacturer’s documentation not maintained on site.', 6, Decimal('0.02264150943396226415')),
#  ('Seafood', '03E', 'Potable water supply inadequate. Water or ice not potable or from unapproved source.  Cross connection in potable water supply system observed.', 1, Decimal('0.00030978934324659232')),
#  ('Russian', '05H', 'No facilities available to wash, rinse and sanitize utensils and/or equipment.', 1, Decimal('0.00049950049950049950')),
#  ('Moroccan', '03C', 'Eggs found dirty/cracked; liquid, frozen or powdered eggs not pasteurized.', 1, Decimal('0.00358422939068100358')),
#  ('Irish', '05H', 'No facilities available to wash, rinse and sanitize utensils and/or equipment.', 7, Decimal('0.00159926890564313457')),
#  ('Ice Cream, Gelato, Yogurt, Ices', '09C', 'Food contact surface not properly maintained.', 35, Decimal('0.00958641468090933991')),
#  ('Ethiopian', '10J', '""Wash hands” sign not posted at hand wash facility.', 2, Decimal('0.00673400673400673401')),
#  ('Seafood', '06A', 'Personal cleanliness inadequate. Outer garment soiled with possible contaminant.  Effective hair restraint not worn in an area where food is prepared.', 58, Decimal('0.01796778190830235440')),
#  ('Caribbean', '06D', 'Food contact surface not properly washed, rinsed and sanitized after each use and following any activity when contamination may have occurred.', 386, Decimal('0.02405134276278895881')),
#  ('Chinese', '04I', 'Unprotected food re-served.', 8, Decimal('0.00013201537979174574')),
#  ('Korean', '04F', 'Food, food preparation area, food storage area, area used by employees or patrons, contaminated by sewage or liquid waste.', 5, Decimal('0.00072484778196578718')),
#  ('Peruvian', '10G', 'Food service operation occurring in room used as living or sleeping quarters.', 1, Decimal('0.00053248136315228967')),
#  ('Continental', '04H', 'Raw, cooked or prepared food is adulterated, contaminated, cross-contaminated, or not discarded in accordance with HACCP plan.', 32, Decimal('0.03268641470888661900')),
#  ('Barbecue', '06C', 'Food not protected from potential source of contamination during storage, preparation, transportation, display or service.', 28, Decimal('0.03535353535353535354')),
#  ('Vietnamese/Cambodian/Malaysia', '10A', 'Toilet facility not maintained and provided with toilet paper, waste receptacle and self-closing door.', 5, Decimal('0.00273822562979189485')),
#  ('Czech', '16B', 'The original nutritional fact labels and/or ingredient label for a cooking oil, shortening or margarine or food item sold in bulk, or acceptable manufacturer’s documentation not maintained on site.', 3, Decimal('0.02380952380952380952')),
#  ('Brazilian', '20A', 'Food allergy information poster not conspicuously posted where food is being prepared or processed by food workers.', 1, Decimal('0.00149925037481259370')),
#  ('American ', '20E', 'Letter Grade or Grade Pending card not conspicuously posted and visible to passersby.', 113, Decimal('0.00090821411348657772')),
#  ('German', '08C', 'Pesticide use not in accordance with label or applicable laws. Prohibited chemical used/stored. Open bait station used.', 8, Decimal('0.00947867298578199052')),
#  ('Tapas', '03B', 'Shellfish not from approved source, improperly tagged/labeled; tags not retained for 90 days.', 3, Decimal('0.00497512437810945274')),
#  ('Caribbean', '04N', 'Filth flies or food/refuse/sewage-associated (FRSA) flies present in facility’s food and/or non-food areas. Filth flies include house flies, little house flies, blow flies, bottle flies and flesh flies. Food/refuse/sewage-associated flies include fruit flies, drain flies and Phorid flies.', 926, Decimal('0.05769829895943672503')),
#  ('Salads', '02G', 'Cold food item held above 41º F (smoked fish and reduced oxygen packaged foods above 38 ºF) except during necessary preparation.', 78, Decimal('0.14130434782608695652')),
#  ('Chinese/Cuban', '04M', "Live roaches present in facility's food and/or non-food areas.", 26, Decimal('0.05977011494252873563')),
#  ('Hotdogs', '03A', 'Food from unapproved or unknown source or home canned. Reduced oxygen packaged (ROP) fish not frozen before processing; or ROP foods prepared on premises transported to another site.', 1, Decimal('0.00231481481481481481')),
#  ('Vietnamese/Cambodian/Malaysia', '06B', 'Tobacco use, eating, or drinking from open container in food preparation, food storage or dishwashing area observed.', 16, Decimal('0.00876232201533406353')),
#  ('Korean', '05F', 'Insufficient or no refrigerated or hot holding equipment to keep potentially hazardous foods at required temperatures.', 7, Decimal('0.00101478689475210206')),
#  ('Czech', '10A', 'Toilet facility not maintained and provided with toilet paper, waste receptacle and self-closing door.', 2, Decimal('0.01587301587301587302')),
#  ('Café/Coffee/Tea', '16C', 'Caloric content not posted on menus, menu boards or food tags, in a food service establishment that is 1 of 15 or more outlets operating the same typ ... (62 characters truncated) ...  as a franchise or doing business under the same name, for each menu item that is served in portions, the size and content of which are standardized.', 9, Decimal('0.00061170393529531707')),
#  ('Bakery', '04L', "Evidence of mice or live mice present in facility's food and/or non-food areas.", 1390, Decimal('0.08691845922961480740')),
#  ('Italian', '04C', 'Food worker does not use proper utensil to eliminate bare hand contact with food that will not receive adequate additional heat treatment.', 361, Decimal('0.01418523321152108138')),
#  ('Sandwiches', '08A', 'Facility not vermin proof. Harborage or conditions conducive to attracting vermin to the premises and/or allowing vermin to exist.', 543, Decimal('0.08369297163995067818')),
#  ('Delicatessen', '15K', 'Operator failed to make good faith effort to inform smokers of the Smoke-free Act prohibition of smoking.', 1, Decimal('0.00010495382031905961')),
#  ('Chinese/Cuban', '10J', '""Wash hands” sign not posted at hand wash facility.', 1, Decimal('0.00229885057471264368')),
#  ('Café/Coffee/Tea', '16A', 'A food containing artificial trans fat, with 0.5 grams or more of trans fat per serving, is being stored, distributed, held for service, used in preparation of a menu item, or served.', 16, Decimal('0.00108747366274723034')),
#  ('Chicken', '06B', 'Tobacco use, eating, or drinking from open container in food preparation, food storage or dishwashing area observed.', 39, Decimal('0.00530323633396790862')),
#  ('Chinese', '03C', 'Eggs found dirty/cracked; liquid, frozen or powdered eggs not pasteurized.', 54, Decimal('0.00089110381359428373')),
#  ('Hamburgers', '20E', 'Letter Grade or Grade Pending card not conspicuously posted and visible to passersby.', 3, Decimal('0.00039308176100628931')),
#  ('Armenian', '22C', 'Bulb not shielded or shatterproof, in areas where there is extreme heat, temperature changes, or where accidental contact may occur.', 8, Decimal('0.01275917065390749601')),
#  ('Fruits/Vegetables', '04J', 'Appropriately scaled metal stem-type thermometer or thermocouple not provided or used to evaluate temperatures of potentially hazardous foods during cooking, cooling, reheating and holding.', 1, Decimal('0.02000000000000000000')),
#  ('Italian', '15I', '""No Smoking” and/or \'Smoking Permitted” sign not conspicuously posted. Health warning not present on \'Smoking Permitted”', 22, Decimal('0.00086447404613147864')),
#  ('Portuguese', '05H', 'No facilities available to wash, rinse and sanitize utensils and/or equipment.', 1, Decimal('0.00377358490566037736')),
#  ('French', '03C', 'Eggs found dirty/cracked; liquid, frozen or powdered eggs not pasteurized.', 9, Decimal('0.00122265996467871213')),
#  ('Caribbean', '04J', 'Appropriately scaled metal stem-type thermometer or thermocouple not provided or used to evaluate temperatures of potentially hazardous foods during cooking, cooling, reheating and holding.', 241, Decimal('0.01501651193220761418')),
#  ('Chinese', '08C', 'Pesticide use not in accordance with label or applicable laws. Prohibited chemical used/stored. Open bait station used.', 530, Decimal('0.00874601891120315517')),
#  ('Continental', '22C', 'Bulb not shielded or shatterproof, in areas where there is extreme heat, temperature changes, or where accidental contact may occur.', 4, Decimal('0.00408580183861082737')),
#  ('Greek', '04J', 'Appropriately scaled metal stem-type thermometer or thermocouple not provided or used to evaluate temperatures of potentially hazardous foods during cooking, cooling, reheating and holding.', 12, Decimal('0.00477326968973747017')),
#  ('Polish', '02C', 'Hot food item that has been cooked and refrigerated is being held for service without first being reheated to 1 65º F or above within 2 hours.', 2, Decimal('0.00278551532033426184')),
#  ('Russian', '09A', 'Canned food product observed dented and not segregated from other consumable food items.', 6, Decimal('0.00299700299700299700')),
#  ('Eastern European', '06C', 'Food not protected from potential source of contamination during storage, preparation, transportation, display or service.', 68, Decimal('0.04619565217391304348')),
#  ('Nuts/Confectionary', '04H', 'Raw, cooked or prepared food is adulterated, contaminated, cross-contaminated, or not discarded in accordance with HACCP plan.', 1, Decimal('0.01694915254237288136')),
#  ('Indian', '06E', 'Sanitized equipment or utensil, including in-use food dispensing utensil, improperly used or stored.', 253, Decimal('0.03105437584386890880')),
#  ('Pizza', '04F', 'Food, food preparation area, food storage area, area used by employees or patrons, contaminated by sewage or liquid waste.', 6, Decimal('0.00023520188161505292')),
#  ('Pancakes/Waffles', '05D', 'Hand washing facility not provided in or near food preparation area and toilet room. Hot and cold running water at adequate pressure to enable cleanliness of employees not provided at facility. Soap and an acceptable hand-drying device not provided.', 2, Decimal('0.00492610837438423645')),
#  ('Jewish/Kosher', '05C', 'Food contact surface improperly constructed or located. Unacceptable material used.', 2, Decimal('0.00026641800985746636')),
#  ('Pizza/Italian', '22A', 'Nuisance created or allowed to exist. Facility not free from unsafe, hazardous, offensive or annoying conditions.', 25, Decimal('0.00236496074165168858')),
#  ('Moroccan', '04H', 'Raw, cooked or prepared food is adulterated, contaminated, cross-contaminated, or not discarded in accordance with HACCP plan.', 4, Decimal('0.01433691756272401434')),
#  ('Hamburgers', '06A', 'Personal cleanliness inadequate. Outer garment soiled with possible contaminant.  Effective hair restraint not worn in an area where food is prepared.', 153, Decimal('0.02004716981132075472')),
#  ('Soups & Sandwiches', '04H', 'Raw, cooked or prepared food is adulterated, contaminated, cross-contaminated, or not discarded in accordance with HACCP plan.', 11, Decimal('0.01926444833625218914')),
#  ('Hawaiian', '02B', 'Hot food item not held at or above 140º F.', 4, Decimal('0.05882352941176470588')),
#  ('Pizza', '04K', "Evidence of rats or live rats present in facility's food and/or non-food areas.", 123, Decimal('0.00482163857310858487')),
#  ('Thai', '15K', 'Operator failed to make good faith effort to inform smokers of the Smoke-free Act prohibition of smoking.', 2, Decimal('0.00029342723004694836')),
#  ('Pizza/Italian', '16A', 'A food containing artificial trans fat, with 0.5 grams or more of trans fat per serving, is being stored, distributed, held for service, used in preparation of a menu item, or served.', 15, Decimal('0.00141897644499101315')),
#  ('Tex-Mex', '04D', 'Food worker does not wash hands thoroughly after using the toilet, coughing, sneezing, smoking, eating, preparing raw foods or otherwise contaminating hands.', 4, Decimal('0.00141894288754877616')),
#  ('Vegetarian', '10F', 'Non-food contact surface improperly constructed. Unacceptable material used. Non-food contact surface or equipment improperly maintained and/or not properly sealed, raised, spaced or movable to allow accessibility for cleaning on all sides, above and underneath the unit.', 261, Decimal('0.13343558282208588957')),
#  ('Bangladeshi', '06B', 'Tobacco use, eating, or drinking from open container in food preparation, food storage or dishwashing area observed.', 8, Decimal('0.00996264009962640100')),
#  ('Salads', '20D', '“Choking first aid” poster not posted. “Alcohol and pregnancy” warning sign not posted. Resuscitation equipment: exhaled air resuscitation masks (adult & pediatric), latex gloves, sign not posted. Inspection report sign not posted.', 4, Decimal('0.00724637681159420290')),
#  ...]

# %%
# %%sql
#
# -- create a table with ratio of violation type and total number of violations
#
# DROP TABLE IF EXISTS q5_temp4;
# Create temporary table q5_temp4 as
#
# select violcode, count(*) as total_viol_count,
#        count(*) * 1.0 / (select count(*) from q5_temp) as ratio_per_type
# from q5_temp
# group by violcode
# order by violcode;
# Out:
#  * postgresql://docker:***@nycinspection.tditrain.com:5433/NYCinspection
# Done.
# 92 rows affected.
# []

# %%
# %%sql
#
# -- get the glimpse of the data in previous table
#
# select * from q5_temp4;
# Out:
#  * postgresql://docker:***@nycinspection.tditrain.com:5433/NYCinspection
# 92 rows affected.
# [('02A', 498, Decimal('0.00095254125766049746')),
#  ('02B', 24523, Decimal('0.04690596237270758896')),
#  ('02C', 550, Decimal('0.00105200339701460563')),
#  ('02D', 52, Decimal('0.000099462139354108168902')),
#  ('02E', 19, Decimal('0.000036341935533231830945')),
#  ('02F', 10, Decimal('0.000019127334491174647866')),
#  ('02G', 45819, Decimal('0.08763953390511311906')),
#  ('02H', 3160, Decimal('0.00604423769921118873')),
#  ('02I', 42, Decimal('0.000080334804862933521036')),
#  ('03A', 593, Decimal('0.00113425093532665662')),
#  ('03B', 331, Decimal('0.00063311477165788084')),
#  ('03C', 474, Decimal('0.00090663565488167831')),
#  ('03D', 90, Decimal('0.00017214601042057183')),
#  ('03E', 22, Decimal('0.000042080135880584225305')),
#  ('03G', 20, Decimal('0.000038254668982349295732')),
#  ('04A', 9264, Decimal('0.01771956267262419378')),
#  ('04B', 38, Decimal('0.000072683871066463661890')),
#  ('04C', 4726, Decimal('0.00903957828052913858')),
#  ('04D', 496, Decimal('0.00094871579076226253')),
#  ('04E', 324, Decimal('0.00061972563751405859')),
#  ('04F', 89, Decimal('0.00017023327697145437')),
#  ('04G', 16, Decimal('0.000030603735185879436585')),
#  ('04H', 15954, Decimal('0.03051574944722003321')),
#  ('04I', 25, Decimal('0.000047818336227936619664')),
#  ('04J', 6272, Decimal('0.01199666419286473914')),
#  ('04K', 3306, Decimal('0.00632349678278233858')),
#  ('04L', 38306, Decimal('0.07326916750189360611')),
#  ('04M', 14568, Decimal('0.02786470088674322701')),
#  ('04N', 21508, Decimal('0.04113907102361843263')),
#  ('04O', 541, Decimal('0.00103478879597254845')),
#  ('05A', 111, Decimal('0.00021231341285203859')),
#  ('05B', 55, Decimal('0.00010520033970146056')),
#  ('05C', 40, Decimal('0.000076509337964698591463')),
#  ('05D', 5960, Decimal('0.01139989135674009013')),
#  ('05E', 151, Decimal('0.00028882275081673718')),
#  ('05F', 827, Decimal('0.00158183056242014338')),
#  ('05H', 844, Decimal('0.00161434703105514028')),
#  ('05I', 16, Decimal('0.000030603735185879436585')),
#  ('06A', 9381, Decimal('0.01794335248617093716')),
#  ('06B', 3221, Decimal('0.00616091443960735408')),
#  ('06C', 25370, Decimal('0.04852604760411008164')),
#  ('06D', 30966, Decimal('0.05922970398537141458')),
#  ('06E', 13741, Decimal('0.02628287032432308363')),
#  ('06F', 10016, Decimal('0.01915793822636052730')),
#  ('06G', 114, Decimal('0.00021805161319939099')),
#  ('06H', 13, Decimal('0.000024865534838527042226')),
#  ('06I', 23, Decimal('0.000043992869329701690091')),
#  ('07A', 155, Decimal('0.00029647368461320704')),
#  ('08A', 49564, Decimal('0.09480272067205802468')),
#  ('08B', 2400, Decimal('0.00459056027788191549')),
#  ('08C', 6240, Decimal('0.01193545672249298027')),
#  ('09A', 2734, Decimal('0.00522941324988714873')),
#  ('09B', 4364, Decimal('0.00834716877194861633')),
#  ('09C', 6806, Decimal('0.01301806385469346534')),
#  ('10A', 5860, Decimal('0.01120861801182834365')),
#  ('10B', 31331, Decimal('0.05992785169429928923')),
#  ('10C', 479, Decimal('0.00091619932212726563')),
#  ('10D', 4979, Decimal('0.00952349984315585717')),
#  ('10E', 3536, Decimal('0.00676342547607935549')),
#  ('10F', 66420, Decimal('0.12704375569038201112')),
#  ('10G', 115, Decimal('0.00021996434664850845')),
#  ('10H', 8727, Decimal('0.01669242481044811519')),
#  ('10I', 3898, Decimal('0.00745583498465987774')),
#  ('10J', 2472, Decimal('0.00472827708621837295')),
#  ('15E', 6, Decimal('0.000011476400694704788719')),
#  ('15I', 310, Decimal('0.00059294736922641408')),
#  ('15J', 280, Decimal('0.00053556536575289014')),
#  ('15K', 184, Decimal('0.00035194295463761352')),
#  ('15L', 2589, Decimal('0.00495206689976511633')),
#  ('15S', 212, Decimal('0.00040549949121290253')),
#  ('15T', 52, Decimal('0.000099462139354108168902')),
#  ('16A', 725, Decimal('0.00138673175061016197')),
#  ('16B', 4607, Decimal('0.00881196300008416027')),
#  ('16C', 121, Decimal('0.00023144074734321324')),
#  ('16E', 11, Decimal('0.000021040067940292112652')),
#  ('16F', 9, Decimal('0.000017214601042057183079')),
#  ('18A', 66, Decimal('0.00012624040764175268')),
#  ('18B', 25, Decimal('0.000047818336227936619664')),
#  ('18C', 31, Decimal('0.000059294736922641408384')),
#  ('18D', 132, Decimal('0.00025248081528350535')),
#  ('18F', 68, Decimal('0.00013006587453998761')),
#  ('18G', 38, Decimal('0.000072683871066463661890')),
#  ('20A', 879, Decimal('0.00168129270177425155')),
#  ('20B', 18, Decimal('0.000034429202084114366158')),
#  ('20D', 1940, Decimal('0.00371070289128788169')),
#  ('20E', 392, Decimal('0.00074979151205404620')),
#  ('20F', 3031, Decimal('0.00579749508427503577')),
#  ('22A', 1724, Decimal('0.00329755246627850929')),
#  ('22B', 396, Decimal('0.00075744244585051606')),
#  ('22C', 4374, Decimal('0.00836629610643979098')),
#  ('22E', 59, Decimal('0.00011285127349793042')),
#  ('99B', 2257, Decimal('0.00431703939465811802'))]

# %%
# %%sql
#
# DROP TABLE IF EXISTS q5_temp5;
# Create temporary table q5_temp5 as
#
# select q5_temp3.cuisine_name,
#        q5_temp3.violcode,
#        max(q5_temp3.ratio_per_cuisine)/max(q5_temp4.ratio_per_type) as ratio,
#        max(q5_temp3.viol_count) as violations_count
# from q5_temp3 join q5_temp4
# on q5_temp3.violcode = q5_temp4.violcode
# group by q5_temp3.cuisine_name,
#          q5_temp3.violcode;
# Out:
#  * postgresql://docker:***@nycinspection.tditrain.com:5433/NYCinspection
# Done.
# 4398 rows affected.
# []

# %%
# %%sql
#
# select distinct q5_temp5.cuisine_name, valid_violations.violationdesc, q5_temp5.ratio, q5_temp5.violations_count
# from q5_temp5 join valid_violations
# on q5_temp5.violcode = valid_violations.violationcode
# group by q5_temp5.cuisine_name, valid_violations.violationdesc, q5_temp5.ratio, q5_temp5.violations_count
# having q5_temp5.violations_count > 100
# order by q5_temp5.ratio DESC
# limit 20;
# Out:
#  * postgresql://docker:***@nycinspection.tditrain.com:5433/NYCinspection
# 20 rows affected.
# [('Japanese', 'Food worker does not use proper utensil to eliminate bare hand contact with food that will not receive adequate additional heat treatment.', Decimal('3.26769995479263359132'), 541),
#  ('Café/Coffee/Tea', '“Choking first aid” poster not posted. “Alcohol and pregnancy” warning sign not posted. Resuscitation equipment: exhaled air resuscitation masks (adult & pediatric), latex gloves, sign not posted. Inspection report sign not posted.', Decimal('3.16875517198129713207'), 173),
#  ('Juice, Smoothies, Fruit Salads', 'Food Protection Certificate not held by supervisor of food operations.', Decimal('3.11142441077772743159'), 145),
#  ('Donuts', 'Accurate thermometer not provided in refrigerated or hot holding equipment.', Decimal('3.06457739345738295074'), 130),
#  ('Ice Cream, Gelato, Yogurt, Ices', 'Food Protection Certificate not held by supervisor of food operations.', Decimal('2.98326942390212727150'), 193),
#  ('Thai', 'Thawing procedures improper.', Decimal('2.65404432015250685260'), 151),
#  ('Irish', 'Raw, cooked or prepared food is adulterated, contaminated, cross-contaminated, or not discarded in accordance with HACCP plan.', Decimal('2.40328040443210487827'), 321),
#  ('Mexican', 'Food not cooled by an approved method whereby the internal product temperature is reduced from 140º F to 70º F or less within 2 hours, and from 70º F to 41º F or less within 4 additional hours.', Decimal('2.35279643467646848894'), 260),
#  ('Indian', 'Food not cooled by an approved method whereby the internal product temperature is reduced from 140º F to 70º F or less within 2 hours, and from 70º F to 41º F or less within 4 additional hours.', Decimal('2.27446244870753076649'), 112),
#  ('Chinese', 'Thawing procedures improper.', Decimal('2.21615922700457481350'), 1121),
#  ('Caribbean', 'Food not cooled by an approved method whereby the internal product temperature is reduced from 140º F to 70º F or less within 2 hours, and from 70º F to 41º F or less within 4 additional hours.', Decimal('2.12362440658395057414'), 206),
#  ('Soups & Sandwiches', 'Cold food item held above 41º F (smoked fish and reduced oxygen packaged foods above 38 ºF) except during necessary preparation.', Decimal('2.11821333535453539115'), 106),
#  ('Hamburgers', 'Accurate thermometer not provided in refrigerated or hot holding equipment.', Decimal('2.11164752245842700790'), 109),
#  ('Chinese', 'Food worker does not wash hands thoroughly after using the toilet, coughing, sneezing, smoking, eating, preparing raw foods or otherwise contaminating hands.', Decimal('2.10466889957196142988'), 121),
#  ('Middle Eastern', 'Food Protection Certificate not held by supervisor of food operations.', Decimal('2.06662652947043226580'), 117),
#  ('American ', '""No Smoking” and/or \'Smoking Permitted” sign not conspicuously posted. Health warning not present on \'Smoking Permitted”', Decimal('2.04677735661209950969'), 151),
#  ('Donuts', 'Bulb not shielded or shatterproof, in areas where there is extreme heat, temperature changes, or where accidental contact may occur.', Decimal('2.03912803976185810259'), 107),
#  ('American ', 'Ashtray present in smoke-free area.', Decimal('1.92091119939375845964'), 128),
#  ('Spanish', 'Food not cooled by an approved method whereby the internal product temperature is reduced from 140º F to 70º F or less within 2 hours, and from 70º F to 41º F or less within 4 additional hours.', Decimal('1.91892404577146740665'), 151),
#  ('Hamburgers', 'Filth flies or food/refuse/sewage-associated (FRSA) flies present in facility’s food and/or non-food areas. Filth flies include house flies, little house flies, blow flies, bottle flies and flesh flies. Food/refuse/sewage-associated flies include fruit flies, drain flies and Phorid flies.', Decimal('1.91098997243091059882'), 600)]

# %%
violation_by_cuisine = _

# %%
#violation_by_cuisine = [
#    ("Soups & Sandwiches",
 #    "Cold food item held above 41º F (smoked fish and reduced oxygen packaged foods above 38 ºF) "
 #    "except during necessary preparation.",
 #    2.0604766856685517, 106)] * 20

grader.score('sql__violation_by_cuisine', violation_by_cuisine)
# Out:
# ==================
# Your score: 1.0000
# ==================

# %% [markdown]
# *Copyright &copy; 2022 Pragmatic Institute. This content is licensed solely for personal use. Redistribution or publication of this material is strictly prohibited.*
